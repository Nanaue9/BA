# %% [markdown]
# **Course: BA820 - Unsupervised and Unstructured ML**
#
# **Notebook created by: Mohannad Elhamod**

# %% [markdown]
# **Note**: You are **ALLOWED** to use Generative AI for this notebook, but you must properly cite your usage. Be sure to review the syllabus for details on citation requirements and the consequences of failing to cite your sources correctly or simply copy-pasting without meaningful engagement.

# %% [markdown]
# #Analysis of Purchases and Product Recommendations.

# %% [markdown]
# In this notebook, we will work with a dataset of purchases, where each row represents a customer's purchase of a product.
#
# Most column names are self-explanatory. The "Amount" column indicates the quantity of items sold.

# %% [markdown]
# ## Load the Dataset

# %%
### DO NOT CHANGE THIS CODE###

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


url = "https://drive.google.com/uc?export=download&id=1JbXO4RgolhHz1FmVDJpTyFUV4oSEagjA"


# Read the CSV file into a DataFrame and make some edits.
df = pd.read_csv(url, on_bad_lines='skip', encoding="latin1")
df = df.drop('Cust_name', axis=1)
df = df.drop('Product_ID', axis=1)
df.Age = df.Age.astype('int64')
df.Orders = df.Orders.astype('int64')

# Display the first few rows
print(df.dtypes)
df
# Out:
# User_ID               int64
# Gender               object
# Age Group            object
# Age                   int64
# Marital_Status        int64
# State                object
# Zone                 object
# Occupation           object
# Product_Category     object
# Orders                int64
# Amount              float64
# dtype: object
#        User_ID Gender Age Group  Age  Marital_Status           State  \
# 0      1002903      F     26-35   28               0     Maharashtra
# 1      1000732      F     26-35   35               1  Andhra Pradesh
# 2      1001990      F     26-35   35               1   Uttar Pradesh
# 3      1001425      M      0-17   16               0       Karnataka
# 4      1000588      M     26-35   28               1         Gujarat
# ...        ...    ...       ...  ...             ...             ...
# 11246  1000695      M     18-25   19               1     Maharashtra
# 11247  1004089      M     26-35   33               0         Haryana
# 11248  1001209      F     36-45   40               0  Madhya Pradesh
# 11249  1004023      M     36-45   37               0       Karnataka
# 11250  1002744      F     18-25   19               0     Maharashtra
#
#            Zone       Occupation Product_Category  Orders   Amount
# 0       Western       Healthcare             Auto       1  23952.0
# 1      Southern             Govt             Auto       3  23934.0
# 2       Central       Automobile             Auto       3  23924.0
# 3      Southern     Construction             Auto       2  23912.0
# 4       Western  Food Processing             Auto       2  23877.0
# ...         ...              ...              ...     ...      ...
# 11246   Western         Chemical           Office       4    370.0
# 11247  Northern       Healthcare       Veterinary       3    367.0
# 11248   Central          Textile           Office       4    213.0
# 11249  Southern      Agriculture           Office       3    206.0
# 11250   Western       Healthcare           Office       3    188.0
#
# [11251 rows x 11 columns]

# %%
df[df['User_ID'] == 1000695]
# Out:
#        User_ID Gender Age Group  Age  Marital_Status          State      Zone  \
# 3532   1000695      M     18-25   20               1  Uttar Pradesh   Central
# 4465   1000695      M     18-25   22               1    Uttarakhand   Central
# 7438   1000695      M     18-25   18               0         Punjab  Northern
# 9044   1000695      M     18-25   21               0        Haryana  Northern
# 9893   1000695      M     18-25   24               1         Kerala  Southern
# 11246  1000695      M     18-25   19               1    Maharashtra   Western
#
#         Occupation       Product_Category  Orders   Amount
# 3532        Retail                   Food       3  11678.0
# 4465   Hospitality  Electronics & Gadgets       1   9816.0
# 7438    Automobile     Clothing & Apparel       3   6945.0
# 9044    Healthcare     Clothing & Apparel       3   5146.0
# 9893      Aviation     Clothing & Apparel       3   3643.0
# 11246     Chemical                 Office       4    370.0

# %% [markdown]
# ## Data Cleaning and Preprocessing **(2 Points)**

# %% [markdown]
# For data cleaning and preprocessing, follow these steps:
#
# - Use `SimpleImputer` to fill in missing values with the mean of their respective category. (For example, if "Amount" is missing for an "Auto" purchase, replace it with the average "Amount" of all "Auto" purchases.) **(1 Points)**
# - Ensure the "Amount" column is an integer since it represents the number of units sold. **(0.5 Points)**
# - Remove any duplicate entries from the dataset. **(0.5 Points)**

# %%
from sklearn.impute import SimpleImputer
import numpy as np

# Group data by 'Product'
grouped = df.groupby('Product_Category')

# Iterate through each group and fill missing 'Amount' values with the group's mean
mean_imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
for product, group in grouped:
    df.loc[df['Product_Category'] == product, 'Amount'] = mean_imputer.fit_transform(group[['Amount']])
df.Amount = df.Amount.astype('int64')

# Remove duplicate rows
df.drop_duplicates(inplace=True)
df
# Out:
#        User_ID Gender Age Group  Age  Marital_Status           State  \
# 0      1002903      F     26-35   28               0     Maharashtra
# 1      1000732      F     26-35   35               1  Andhra Pradesh
# 2      1001990      F     26-35   35               1   Uttar Pradesh
# 3      1001425      M      0-17   16               0       Karnataka
# 4      1000588      M     26-35   28               1         Gujarat
# ...        ...    ...       ...  ...             ...             ...
# 11246  1000695      M     18-25   19               1     Maharashtra
# 11247  1004089      M     26-35   33               0         Haryana
# 11248  1001209      F     36-45   40               0  Madhya Pradesh
# 11249  1004023      M     36-45   37               0       Karnataka
# 11250  1002744      F     18-25   19               0     Maharashtra
#
#            Zone       Occupation Product_Category  Orders  Amount
# 0       Western       Healthcare             Auto       1   23952
# 1      Southern             Govt             Auto       3   23934
# 2       Central       Automobile             Auto       3   23924
# 3      Southern     Construction             Auto       2   23912
# 4       Western  Food Processing             Auto       2   23877
# ...         ...              ...              ...     ...     ...
# 11246   Western         Chemical           Office       4     370
# 11247  Northern       Healthcare       Veterinary       3     367
# 11248   Central          Textile           Office       4     213
# 11249  Southern      Agriculture           Office       3     206
# 11250   Western       Healthcare           Office       3     188
#
# [11243 rows x 11 columns]

# %% [markdown]
# # Question 1 **(10 Points)**

# %% [markdown]
# You have been tasked with sending personalized promotions to customers based on their purchase history to increase sales across different product categories.
#
# Since the product range is diverse, it's important to match each customer with the most relevant promotions.
#
# To do this, you will focus on **loyal customers**—those who either:
# 1) Frequently make **high-value purchases**, *or*
# 2) Place **multiple orders**.
#
# A customer is considered **loyal** if they have made **more than 20 orders** or bought **more than 80,000 items**.
#
# Using your data analytics skills, answer the following question:
#
# > Based on the *general* purchase patterns of loyal customers, what are the **top two product categories** that you recommend to your most loyal customer, uniquely based on their *personal* purchase history?

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %% [markdown]
# ###Step 1: Identify Purchases Made by Loyal Customers **(3 Points)**

# %%
#Identify loyal customers based on Orders and Amount
loyal_customers = df.groupby('User_ID').agg({
    'Orders': 'sum',
    'Amount': 'sum'
}).reset_index()

# Define a loyal customer as one who has placed more than 20 orders or spent more than 80,000
loyal_customers = loyal_customers[(loyal_customers['Orders'] > 20) | (loyal_customers['Amount'] > 80000)]
loyal_customer_ids = loyal_customers['User_ID']

# Filter the dataset for loyal customers
loyal_df = df[df['User_ID'].isin(loyal_customer_ids)]
loyal_df
# Out:
#        User_ID Gender Age Group  Age  Marital_Status             State  \
# 3      1001425      M      0-17   16               0         Karnataka
# 4      1000588      M     26-35   28               1           Gujarat
# 5      1000588      M     26-35   28               1  Himachal Pradesh
# 7      1002092      F       55+   61               0       Maharashtra
# 8      1003224      M     26-35   35               0     Uttar Pradesh
# ...        ...    ...       ...  ...             ...               ...
# 11237  1000687      M     26-35   29               1           Haryana
# 11240  1001425      F      0-17   12               0             Delhi
# 11241  1003032      F     26-35   33               0             Delhi
# 11242  1004344      F     26-35   27               1             Delhi
# 11247  1004089      M     26-35   33               0           Haryana
#
#            Zone       Occupation Product_Category  Orders  Amount
# 3      Southern     Construction             Auto       2   23912
# 4       Western  Food Processing             Auto       2   23877
# 5      Northern  Food Processing             Auto       1   23877
# 7       Western        IT Sector             Auto       1   20191
# 8       Central             Govt             Auto       2   23809
# ...         ...              ...              ...     ...     ...
# 11237  Northern            Media           Office       2     557
# 11240   Central        IT Sector       Veterinary       1     396
# 11241   Central      Hospitality           Office       3     384
# 11242   Central       Healthcare           Office       2     382
# 11247  Northern       Healthcare       Veterinary       3     367
#
# [2823 rows x 11 columns]

# %% [markdown]
# ### Step 2: Identify Purchase Patterns of Loyal Customers **(4 Points)**
#
# Only consider patterns that appear in at least **5% of all purchases made by loyal customers**.
#
# This helps focus on meaningful trends rather than rare or one-off purchases.

# %%
basket = loyal_df.groupby('User_ID')['Product_Category'].apply(lambda x: ','.join(x)).reset_index()
basket
# Out:
#      User_ID                                   Product_Category
# 0    1000033  Furniture,Sports Products,Food,Sports Products...
# 1    1000036  Furniture,Food,Electronics & Gadgets,Clothing ...
# 2    1000053  Footwear & Shoes,Auto,Clothing & Apparel,Cloth...
# 3    1000148  Furniture,Food,Footwear & Shoes,Footwear & Sho...
# 4    1000151  Stationery,Tupperware,Food,Food,Food,Books,Ele...
# ..       ...                                                ...
# 267  1005837  Food,Food,Food,Food,Electronics & Gadgets,Elec...
# 268  1005954  Footwear & Shoes,Footwear & Shoes,Food,Food,Fo...
# 269  1006000  Food,Footwear & Shoes,Sports Products,Games & ...
# 270  1006016  Footwear & Shoes,Footwear & Shoes,Footwear & S...
# 271  1006036  Food,Food,Food,Games & Toys,Food,Electronics &...
#
# [272 rows x 2 columns]

# %%
# Convert the text in the table to a list of items
data_column = basket['Product_Category']
data = list(data_column.apply(lambda x: x.split(',')))

# %%
#What are the unique values?

flat_list = []
for lst in data:
  flat_list = flat_list + lst
set(flat_list)
# Out:
# {'Auto',
#  'Beauty',
#  'Books',
#  'Clothing & Apparel',
#  'Decor',
#  'Electronics & Gadgets',
#  'Food',
#  'Footwear & Shoes',
#  'Furniture',
#  'Games & Toys',
#  'Hand & Power Tools',
#  'Household items',
#  'Office',
#  'Pet Care',
#  'Sports Products',
#  'Stationery',
#  'Tupperware',
#  'Veterinary'}

# %%
# Transform data
te = TransactionEncoder()
transactions = te.fit(data).transform(data) # or fit_transform(data)

# Create a dataframe from the data
df_encoded = pd.DataFrame(transactions, columns=te.columns_)
df_encoded
# Out:
#       Auto  Beauty  Books  Clothing & Apparel  Decor  Electronics & Gadgets  \
# 0    False   False  False                True  False                  False
# 1    False   False  False                True  False                   True
# 2     True   False  False                True  False                  False
# 3    False   False  False                True  False                  False
# 4    False   False   True               False  False                   True
# ..     ...     ...    ...                 ...    ...                    ...
# 267  False   False  False                True  False                   True
# 268  False    True  False                True   True                   True
# 269  False   False  False                True  False                   True
# 270  False   False  False                True  False                   True
# 271  False    True  False                True  False                   True
#
#       Food  Footwear & Shoes  Furniture  Games & Toys  Hand & Power Tools  \
# 0     True             False       True          True               False
# 1     True             False       True         False               False
# 2    False              True      False         False               False
# 3     True              True       True         False               False
# 4     True             False      False         False               False
# ..     ...               ...        ...           ...                 ...
# 267   True             False      False         False               False
# 268   True              True      False         False               False
# 269   True              True      False          True               False
# 270   True              True      False         False               False
# 271   True             False      False          True               False
#
#      Household items  Office  Pet Care  Sports Products  Stationery  \
# 0              False   False     False             True       False
# 1              False   False     False            False       False
# 2              False    True     False            False       False
# 3              False    True      True             True       False
# 4              False   False     False            False        True
# ..               ...     ...       ...              ...         ...
# 267            False   False     False            False       False
# 268            False   False      True            False       False
# 269            False   False     False             True       False
# 270            False    True     False            False       False
# 271            False   False     False             True       False
#
#      Tupperware  Veterinary
# 0         False       False
# 1         False       False
# 2         False       False
# 3         False       False
# 4          True       False
# ..          ...         ...
# 267       False       False
# 268       False       False
# 269       False       False
# 270       False       False
# 271       False       False
#
# [272 rows x 18 columns]

# %%
# Let's find the most frequent itemsets.
frequent_itemsets = apriori(df_encoded, min_support=0.05, use_colnames=True)
frequent_itemsets.sort_values(by="support")
# Out:
#       support                                           itemsets
# 75   0.051471                              (Furniture, Pet Care)
# 168  0.051471                   (Footwear & Shoes, Office, Food)
# 161  0.051471  (Furniture, Electronics & Gadgets, Sports Prod...
# 219  0.051471  (Furniture, Clothing & Apparel, Electronics & ...
# 212  0.051471  (Veterinary, Clothing & Apparel, Electronics &...
# ..        ...                                                ...
# 47   0.716912                      (Electronics & Gadgets, Food)
# 5    0.790441                            (Electronics & Gadgets)
# 33   0.794118                         (Clothing & Apparel, Food)
# 3    0.875000                               (Clothing & Apparel)
# 6    0.911765                                             (Food)
#
# [254 rows x 2 columns]

# %%
#Let's find the rules of interest.
rules = association_rules(frequent_itemsets, metric="support", min_threshold=0.05, num_itemsets=frequent_itemsets.shape[0])
rules = rules[rules["lift"] >  1]
rules.sort_values(by=["support", "confidence"])
# Out:
#                                  antecedents  \
# 655                                   (Food)
# 673                                   (Food)
# 1029                                  (Food)
# 1695                                  (Food)
# 439                     (Clothing & Apparel)
# ...                                      ...
# 362   (Footwear & Shoes, Clothing & Apparel)
# 35                      (Clothing & Apparel)
# 34                        (Footwear & Shoes)
# 81                                    (Food)
# 80                        (Footwear & Shoes)
#
#                                             consequents  antecedent support  \
# 655                          (Footwear & Shoes, Office)            0.911765
# 673                      (Stationery, Footwear & Shoes)            0.911765
# 1029        (Footwear & Shoes, Household items, Beauty)            0.911765
# 1695  (Clothing & Apparel, Electronics & Gadgets, Ho...            0.911765
# 439                          (Footwear & Shoes, Office)            0.875000
# ...                                                 ...                 ...
# 362                                              (Food)            0.547794
# 35                                   (Footwear & Shoes)            0.875000
# 34                                 (Clothing & Apparel)            0.625000
# 81                                   (Footwear & Shoes)            0.911765
# 80                                               (Food)            0.625000
#
#       consequent support   support  confidence      lift  representativity  \
# 655             0.055147  0.051471    0.056452  1.023656               1.0
# 673             0.051471  0.051471    0.056452  1.096774               1.0
# 1029            0.051471  0.051471    0.056452  1.096774               1.0
# 1695            0.055147  0.051471    0.056452  1.023656               1.0
# 439             0.055147  0.051471    0.058824  1.066667               1.0
# ...                  ...       ...         ...       ...               ...
# 362             0.911765  0.503676    0.919463  1.008443               1.0
# 35              0.625000  0.547794    0.626050  1.001681               1.0
# 34              0.875000  0.547794    0.876471  1.001681               1.0
# 81              0.625000  0.580882    0.637097  1.019355               1.0
# 80              0.911765  0.580882    0.929412  1.019355               1.0
#
#       leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 655   0.001189    1.001383       0.261905  0.056225   0.001381    0.494892
# 673   0.004542    1.005279       1.000000  0.056452   0.005251    0.528226
# 1029  0.004542    1.005279       1.000000  0.056452   0.005251    0.528226
# 1695  0.001189    1.001383       0.261905  0.056225   0.001381    0.494892
# 439   0.003217    1.003906       0.500000  0.058577   0.003891    0.496078
# ...        ...         ...            ...       ...        ...         ...
# 362   0.004217    1.095588       0.018515  0.526923   0.087248    0.735941
# 35    0.000919    1.002809       0.013423  0.575290   0.002801    0.751261
# 34    0.000919    1.011905       0.004474  0.575290   0.011765    0.751261
# 81    0.011029    1.033333       0.215190  0.607692   0.032258    0.783254
# 80    0.011029    1.250000       0.050633  0.607692   0.200000    0.783254
#
# [759 rows x 14 columns]

# %% [markdown]
# ### Step 3: Recommend the Top Two Product Categories **(3 Points)**
# Using the identified purchase patterns, determine the two most relevant product categories for your top loyal customer, based on their unique purchase history.

# %%
loyal_customers.sort_values(by=['Amount'], ascending=False)
# Out:
#       User_ID  Orders  Amount
# 1045  1001680      58  281034
# 1197  1001941      52  239147
# 2134  1003476      57  220435
# 1628  1002665      50  201104
# 2355  1003808      55  197660
# ...       ...     ...     ...
# 2979  1004823      21   50210
# 2381  1003850      22   48572
# 2876  1004647      24   48351
# 1772  1002895      22   37174
# 3135  1005070      21   36345
#
# [272 rows x 3 columns]

# %%
# Find the Top Loyal Customer based on Total Amount or Total Orders
top_loyal_customer = loyal_customers.sort_values(by=['Amount'], ascending=False).head(1)
print(top_loyal_customer)
# Out:
#       User_ID  Orders  Amount
# 1045  1001680      58  281034

# %%
customer_id = top_loyal_customer.iloc[0]['User_ID']

print(f"\nRecommended Product Categories for Customer {customer_id}:")

# Products that the customer has already bought
purchased_products = df[df['User_ID'] == customer_id]['Product_Category'].unique()
# Rules where the antecedent contains products the customer has bought
recommendations = rules[rules['antecedents'].apply(lambda x: all(item in purchased_products for item in x))]
# Get top recommendation: highest lift
top_recommendations = recommendations.sort_values(by='lift', ascending=False)
top_recommendations
# Out:
# Recommended Product Categories for Customer 1001680:
#                                             antecedents  \
# 1737  (Footwear & Shoes, Electronics & Gadgets, Spor...
# 1726  (Footwear & Shoes, Clothing & Apparel, Electro...
# 1746           (Sports Products, Electronics & Gadgets)
# 1748                (Footwear & Shoes, Sports Products)
# 988   (Sports Products, Footwear & Shoes, Electronic...
# ...                                                 ...
# 1104        (Clothing & Apparel, Electronics & Gadgets)
# 319                             (Electronics & Gadgets)
# 1661                                             (Food)
# 910                            (Footwear & Shoes, Food)
# 1898                (Footwear & Shoes, Sports Products)
#
#                                             consequents  antecedent support  \
# 1737                       (Clothing & Apparel, Beauty)            0.117647
# 1726                                           (Beauty)            0.102941
# 1746     (Footwear & Shoes, Clothing & Apparel, Beauty)            0.194853
# 1748  (Clothing & Apparel, Electronics & Gadgets, Be...            0.147059
# 988                                            (Beauty)            0.117647
# ...                                                 ...                 ...
# 1104                               (Games & Toys, Food)            0.691176
# 319                     (Furniture, Clothing & Apparel)            0.790441
# 1661  (Clothing & Apparel, Electronics & Gadgets, Be...            0.911765
# 910                     (Electronics & Gadgets, Beauty)            0.580882
# 1898  (Clothing & Apparel, Electronics & Gadgets, Food)            0.147059
#
#       consequent support   support  confidence      lift  representativity  \
# 1737            0.268382  0.051471    0.437500  1.630137               1.0
# 1726            0.312500  0.051471    0.500000  1.600000               1.0
# 1746            0.172794  0.051471    0.264151  1.528703               1.0
# 1748            0.231618  0.051471    0.350000  1.511111               1.0
# 988             0.312500  0.055147    0.468750  1.500000               1.0
# ...                  ...       ...         ...       ...               ...
# 1104            0.286765  0.198529    0.287234  1.001637               1.0
# 319             0.264706  0.209559    0.265116  1.001550               1.0
# 1661            0.084559  0.077206    0.084677  1.001403               1.0
# 910             0.272059  0.158088    0.272152  1.000342               1.0
# 1898            0.625000  0.091912    0.625000  1.000000               1.0
#
#       leverage  conviction  zhangs_metric   jaccard     certainty  kulczynski
# 1737  0.019896    1.300654       0.438095  0.153846  2.311558e-01    0.314640
# 1726  0.019301    1.375000       0.418033  0.141414  2.727273e-01    0.332353
# 1746  0.017801    1.124152       0.429550  0.162791  1.104403e-01    0.281012
# 1748  0.017409    1.182127       0.396552  0.157303  1.540670e-01    0.286111
# 988   0.018382    1.294118       0.377778  0.147059  2.272727e-01    0.322610
# ...        ...         ...            ...       ...           ...         ...
# 1104  0.000324    1.000658       0.005291  0.254717  6.580390e-04    0.489771
# 319   0.000324    1.000558       0.007387  0.247826  5.581395e-04    0.528391
# 1661  0.000108    1.000130       0.015873  0.084000  1.295505e-04    0.498860
# 910   0.000054    1.000128       0.000816  0.227513  1.278609e-04    0.426616
# 1898  0.000000    1.000000       0.000000  0.135135  2.960595e-16    0.386029
#
# [371 rows x 14 columns]

# %%
# Consequent of the bought items, which are the recommended products
recommended_products = top_recommendations.head(1)['consequents'].apply(lambda x: list(x)).explode().unique()
print(recommended_products)
# Out:
# ['Clothing & Apparel' 'Beauty']

# %% [markdown]
# By using Market Basket Analysis and refining the recommendation engine based on the past purchase behavior of loyal customers, we can send personalized promotions that suggest complementary products. The top loyal customer should be recommended Beauty and Clothing products.

# %% [markdown]
# # Question 2 **(5 Points)**

# %% [markdown]
# *Knowing nothing else about the customer*, what product categories would you *uniquely* recommend to a female customer aged 26-35?
#
#
# 💡 **Hint:** Look for rules that specifically apply to this demographic.

# %%
# To solve this, we need to encode all of product categories, gender, and age group.

basket = df.groupby('User_ID')[['Product_Category', 'Gender', 'Age Group']]
basket = basket.agg({
    'Product_Category': lambda x: ','.join(map(str, x)),
    'Gender': 'first',
    'Age Group': 'first'
}).reset_index()
basket = basket.reset_index()
basket
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       index  User_ID                                   Product_Category  \
# 0         0  1000001                              Electronics & Gadgets
# 1         1  1000002                                 Clothing & Apparel
# 2         2  1000003                              Footwear & Shoes,Food
# 3         3  1000004                             Footwear & Shoes,Decor
# 4         4  1000005                   Footwear & Shoes,Sports Products
# ...     ...      ...                                                ...
# 3750   3750  1006035  Clothing & Apparel,Clothing & Apparel,Clothing...
# 3751   3751  1006036  Food,Food,Food,Games & Toys,Food,Electronics &...
# 3752   3752  1006037                            Food,Clothing & Apparel
# 3753   3753  1006039  Electronics & Gadgets,Clothing & Apparel,House...
# 3754   3754  1006040  Footwear & Shoes,Footwear & Shoes,Sports Produ...
#
#      Gender Age Group
# 0         F      0-17
# 1         F       55+
# 2         F     26-35
# 3         F     46-50
# 4         F     26-35
# ...     ...       ...
# 3750      M     26-35
# 3751      M     26-35
# 3752      M     46-50
# 3753      M     46-50
# 3754      F     26-35
#
# [3755 rows x 5 columns]

# %%
#Convert the text in the table to a list of items
data_column = basket['Product_Category']
data = list(basket.apply(lambda x: x['Product_Category'].split(',') + [x['Gender'], x['Age Group']], axis=1))
data
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [['Electronics & Gadgets', 'F', '0-17'],
#  ['Clothing & Apparel', 'F', '55+'],
#  ['Footwear & Shoes', 'Food', 'F', '26-35'],
#  ['Footwear & Shoes', 'Decor', 'F', '46-50'],
#  ['Footwear & Shoes', 'Sports Products', 'F', '26-35'],
#  ['Food', 'Electronics & Gadgets', 'F', '36-45'],
#  ['Footwear & Shoes', 'Sports Products', 'Clothing & Apparel', 'F', '26-35'],
#  ['Footwear & Shoes', 'Household items', 'F', '26-35'],
#  ['Food',
#   'Furniture',
#   'Clothing & Apparel',
#   'Games & Toys',
#   'Beauty',
#   'M',
#   '36-45'],
#  ['Food', 'Electronics & Gadgets', 'Clothing & Apparel', 'F', '46-50'],
#  ['Food', 'Clothing & Apparel', 'F', '26-35'],
#  ['Sports Products', 'M', '36-45'],
#  ['Footwear & Shoes', 'Games & Toys', 'M', '51-55'],
#  ['Clothing & Apparel', 'Furniture', 'M', '18-25'],
#  ['Food', 'Clothing & Apparel', 'F', '0-17'],
#  ['Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '18-25'],
#  ['Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Household items',
#   'F',
#   '36-45'],
#  ['Games & Toys', 'Food', 'M', '26-35'],
#  ['Food',
#   'Furniture',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Clothing & Apparel',
#   'F',
#   '26-35'],
#  ['Clothing & Apparel', 'M', '26-35'],
#  ['Games & Toys', 'F', '36-45'],
#  ['Food', 'Food', 'M', '36-45'],
#  ['Clothing & Apparel', 'F', '55+'],
#  ['Furniture',
#   'Sports Products',
#   'Food',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Food',
#   'Games & Toys',
#   'Clothing & Apparel',
#   'M',
#   '46-50'],
#  ['Food', 'M', '18-25'],
#  ['Food', 'Decor', 'F', '46-50'],
#  ['Furniture',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '26-35'],
#  ['Clothing & Apparel', 'M', '26-35'],
#  ['Furniture', 'Household items', 'F', '26-35'],
#  ['Footwear & Shoes', 'M', '46-50'],
#  ['Beauty',
#   'Clothing & Apparel',
#   'Stationery',
#   'Household items',
#   'Veterinary',
#   'M',
#   '46-50'],
#  ['Electronics & Gadgets', 'Electronics & Gadgets', 'Beauty', 'F', '26-35'],
#  ['Food', 'F', '18-25'],
#  ['Footwear & Shoes',
#   'Auto',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Office',
#   'F',
#   '26-35'],
#  ['Food', 'F', '18-25'],
#  ['Footwear & Shoes', 'Footwear & Shoes', 'Household items', 'F', '26-35'],
#  ['Electronics & Gadgets', 'M', '51-55'],
#  ['Household items', 'F', '26-35'],
#  ['Food',
#   'Food',
#   'Books',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Office',
#   'M',
#   '36-45'],
#  ['Clothing & Apparel', 'F', '18-25'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Household items',
#   'F',
#   '36-45'],
#  ['Food', 'Decor', 'Clothing & Apparel', 'F', '18-25'],
#  ['Furniture', 'Clothing & Apparel', 'M', '26-35'],
#  ['Footwear & Shoes', 'F', '26-35'],
#  ['Furniture', 'Games & Toys', 'Clothing & Apparel', 'M', '0-17'],
#  ['Electronics & Gadgets', 'F', '36-45'],
#  ['Clothing & Apparel', 'F', '18-25'],
#  ['Sports Products', 'Clothing & Apparel', 'Food', 'M', '46-50'],
#  ['Food', 'Clothing & Apparel', 'F', '55+'],
#  ['Food', 'M', '26-35'],
#  ['Food', 'Clothing & Apparel', 'M', '26-35'],
#  ['Clothing & Apparel', 'Clothing & Apparel', 'Beauty', 'M', '0-17'],
#  ['Clothing & Apparel', 'Clothing & Apparel', 'M', '46-50'],
#  ['Electronics & Gadgets', 'M', '55+'],
#  ['Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'M',
#   '55+'],
#  ['Footwear & Shoes', 'F', '36-45'],
#  ['Furniture', 'Food', 'Food', 'Clothing & Apparel', 'M', '18-25'],
#  ['Food', 'Clothing & Apparel', 'F', '26-35'],
#  ['Electronics & Gadgets', 'Electronics & Gadgets', 'F', '26-35'],
#  ['Food', 'F', '46-50'],
#  ['Electronics & Gadgets', 'M', '26-35'],
#  ['Food', 'Furniture', 'Food', 'M', '36-45'],
#  ['Sports Products', 'M', '36-45'],
#  ['Sports Products', 'F', '36-45'],
#  ['Electronics & Gadgets', 'M', '18-25'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Sports Products',
#   'F',
#   '36-45'],
#  ['Clothing & Apparel', 'Clothing & Apparel', 'F', '46-50'],
#  ['Clothing & Apparel', 'M', '36-45'],
#  ['Electronics & Gadgets', 'Veterinary', 'F', '46-50'],
#  ['Electronics & Gadgets', 'M', '36-45'],
#  ['Auto', 'F', '18-25'],
#  ['Electronics & Gadgets', 'F', '26-35'],
#  ['Food', 'Furniture', 'Books', 'Decor', 'Clothing & Apparel', 'F', '26-35'],
#  ['Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Household items',
#   'M',
#   '36-45'],
#  ['Electronics & Gadgets', 'M', '0-17'],
#  ['Auto', 'F', '36-45'],
#  ['Footwear & Shoes',
#   'Food',
#   'Food',
#   'Sports Products',
#   'Food',
#   'Decor',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '36-45'],
#  ['Footwear & Shoes', 'F', '46-50'],
#  ['Electronics & Gadgets', 'F', '18-25'],
#  ['Clothing & Apparel', 'M', '46-50'],
#  ['Pet Care', 'Pet Care', 'F', '26-35'],
#  ['Sports Products', 'F', '36-45'],
#  ['Food',
#   'Food',
#   'Sports Products',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'F',
#   '18-25'],
#  ['Clothing & Apparel', 'M', '26-35'],
#  ['Games & Toys',
#   'Games & Toys',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Food',
#   'F',
#   '26-35'],
#  ['Food',
#   'Sports Products',
#   'Food',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Beauty',
#   'Clothing & Apparel',
#   'F',
#   '18-25'],
#  ['Footwear & Shoes', 'Games & Toys', 'M', '46-50'],
#  ['Electronics & Gadgets', 'F', '18-25'],
#  ['Household items', 'M', '26-35'],
#  ['Games & Toys', 'Clothing & Apparel', 'F', '36-45'],
#  ['Electronics & Gadgets', 'F', '18-25'],
#  ['Food', 'Clothing & Apparel', 'Household items', 'M', '36-45'],
#  ['Electronics & Gadgets', 'F', '18-25'],
#  ['Furniture',
#   'Food',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Pet Care',
#   'Pet Care',
#   'Office',
#   'F',
#   '51-55'],
#  ['Food',
#   'Clothing & Apparel',
#   'Household items',
#   'Beauty',
#   'Pet Care',
#   'F',
#   '26-35'],
#  ['Food', 'Electronics & Gadgets', 'Pet Care', 'F', '36-45'],
#  ['Stationery',
#   'Tupperware',
#   'Food',
#   'Food',
#   'Food',
#   'Books',
#   'Electronics & Gadgets',
#   'M',
#   '26-35'],
#  ['Food', 'F', '0-17'],
#  ['Footwear & Shoes', 'F', '51-55'],
#  ['Food', 'Electronics & Gadgets', 'F', '36-45'],
#  ['Clothing & Apparel', 'Electronics & Gadgets', 'M', '46-50'],
#  ['Footwear & Shoes',
#   'Furniture',
#   'Food',
#   'Footwear & Shoes',
#   'Books',
#   'Auto',
#   'Electronics & Gadgets',
#   'Beauty',
#   'F',
#   '36-45'],
#  ['Footwear & Shoes',
#   'Food',
#   'Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'F',
#   '46-50'],
#  ['Clothing & Apparel', 'M', '18-25'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'F',
#   '18-25'],
#  ['Clothing & Apparel', 'Beauty', 'F', '18-25'],
#  ['Furniture', 'M', '26-35'],
#  ['Food', 'M', '51-55'],
#  ['Food',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'F',
#   '26-35'],
#  ['Tupperware',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Beauty',
#   'F',
#   '26-35'],
#  ['Beauty', 'F', '26-35'],
#  ['Sports Products', 'Clothing & Apparel', 'M', '26-35'],
#  ['Clothing & Apparel', 'F', '51-55'],
#  ['Stationery', 'M', '55+'],
#  ['Stationery', 'Clothing & Apparel', 'Household items', 'F', '26-35'],
#  ['Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'F',
#   '46-50'],
#  ['Food', 'Clothing & Apparel', 'F', '18-25'],
#  ['Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'F',
#   '18-25'],
#  ['Clothing & Apparel', 'Pet Care', 'M', '46-50'],
#  ['Food', 'M', '26-35'],
#  ['Electronics & Gadgets', 'F', '46-50'],
#  ['Food', 'F', '18-25'],
#  ['Auto',
#   'Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Food',
#   'Food',
#   'M',
#   '46-50'],
#  ['Footwear & Shoes', 'Electronics & Gadgets', 'Office', 'M', '55+'],
#  ['Food', 'Sports Products', 'F', '26-35'],
#  ['Sports Products', 'F', '18-25'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Veterinary',
#   'F',
#   '18-25'],
#  ['Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Household items',
#   'M',
#   '46-50'],
#  ['Footwear & Shoes',
#   'Games & Toys',
#   'Games & Toys',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Sports Products',
#   'Clothing & Apparel',
#   'M',
#   '26-35'],
#  ['Furniture', 'F', '18-25'],
#  ['Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '26-35'],
#  ['Pet Care', 'F', '18-25'],
#  ['Electronics & Gadgets', 'Books', 'M', '36-45'],
#  ['Food', 'Food', 'Clothing & Apparel', 'Food', 'F', '18-25'],
#  ['Food', 'Footwear & Shoes', 'Electronics & Gadgets', 'F', '26-35'],
#  ['Electronics & Gadgets', 'Food', 'F', '36-45'],
#  ['Clothing & Apparel', 'F', '26-35'],
#  ['Food', 'F', '36-45'],
#  ['Electronics & Gadgets', 'Electronics & Gadgets', 'F', '36-45'],
#  ['Auto', 'F', '46-50'],
#  ['Furniture', 'Electronics & Gadgets', 'Books', 'F', '26-35'],
#  ['Auto',
#   'Sports Products',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'F',
#   '18-25'],
#  ['Office', 'F', '36-45'],
#  ['Footwear & Shoes',
#   'Food',
#   'Food',
#   'Sports Products',
#   'Books',
#   'Electronics & Gadgets',
#   'Furniture',
#   'Food',
#   'Clothing & Apparel',
#   'Decor',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'F',
#   '46-50'],
#  ['Food', 'Clothing & Apparel', 'Clothing & Apparel', 'F', '26-35'],
#  ['Clothing & Apparel', 'Clothing & Apparel', 'Pet Care', 'F', '26-35'],
#  ['Food', 'Food', 'Electronics & Gadgets', 'F', '18-25'],
#  ['Furniture',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'F',
#   '46-50'],
#  ['Footwear & Shoes', 'Clothing & Apparel', 'F', '26-35'],
#  ['Household items', 'M', '46-50'],
#  ['Clothing & Apparel', 'F', '36-45'],
#  ['Footwear & Shoes',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Pet Care',
#   'M',
#   '26-35'],
#  ['Clothing & Apparel', 'F', '26-35'],
#  ['Electronics & Gadgets', 'F', '26-35'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Games & Toys',
#   'Clothing & Apparel',
#   'Veterinary',
#   'M',
#   '51-55'],
#  ['Food', 'F', '18-25'],
#  ['Clothing & Apparel', 'Beauty', 'Pet Care', 'F', '51-55'],
#  ['Food',
#   'Sports Products',
#   'Electronics & Gadgets',
#   'Office',
#   'Office',
#   'M',
#   '18-25'],
#  ['Clothing & Apparel', 'F', '51-55'],
#  ['Footwear & Shoes',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Games & Toys',
#   'Clothing & Apparel',
#   'Beauty',
#   'Pet Care',
#   'F',
#   '36-45'],
#  ['Sports Products', 'M', '18-25'],
#  ['Food', 'F', '55+'],
#  ['Beauty', 'F', '26-35'],
#  ['Electronics & Gadgets', 'Beauty', 'Clothing & Apparel', 'F', '36-45'],
#  ['Food', 'Electronics & Gadgets', 'F', '46-50'],
#  ['Electronics & Gadgets', 'Clothing & Apparel', 'F', '18-25'],
#  ['Food', 'F', '26-35'],
#  ['Clothing & Apparel', 'F', '26-35'],
#  ['Household items', 'F', '18-25'],
#  ['Furniture',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'M',
#   '26-35'],
#  ['Electronics & Gadgets', 'Clothing & Apparel', 'M', '26-35'],
#  ['Food', 'M', '26-35'],
#  ['Food',
#   'Food',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Food',
#   'Sports Products',
#   'Electronics & Gadgets',
#   'Food',
#   'Electronics & Gadgets',
#   'F',
#   '36-45'],
#  ['Food', 'M', '36-45'],
#  ['Food', 'Food', 'Clothing & Apparel', 'F', '36-45'],
#  ['Electronics & Gadgets', 'Clothing & Apparel', 'M', '18-25'],
#  ['Furniture',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Beauty',
#   'Food',
#   'Veterinary',
#   'F',
#   '18-25'],
#  ['Food',
#   'Food',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '18-25'],
#  ['Electronics & Gadgets', 'F', '18-25'],
#  ['Clothing & Apparel', 'F', '26-35'],
#  ['Electronics & Gadgets', 'M', '36-45'],
#  ['Food', 'Furniture', 'F', '46-50'],
#  ['Footwear & Shoes', 'Electronics & Gadgets', 'F', '51-55'],
#  ['Furniture', 'Clothing & Apparel', 'Household items', 'M', '36-45'],
#  ['Footwear & Shoes',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Beauty',
#   'F',
#   '26-35'],
#  ['Sports Products', 'Clothing & Apparel', 'M', '36-45'],
#  ['Food', 'Furniture', 'F', '51-55'],
#  ['Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'F',
#   '36-45'],
#  ['Food', 'Decor', 'Electronics & Gadgets', 'F', '55+'],
#  ['Electronics & Gadgets', 'F', '18-25'],
#  ['Food', 'F', '18-25'],
#  ['Tupperware', 'M', '18-25'],
#  ['Electronics & Gadgets', 'Clothing & Apparel', 'F', '26-35'],
#  ['Electronics & Gadgets', 'Clothing & Apparel', 'F', '26-35'],
#  ['Food',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Household items',
#   'Electronics & Gadgets',
#   'Decor',
#   'F',
#   '18-25'],
#  ['Food',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Clothing & Apparel',
#   'F',
#   '18-25'],
#  ['Food',
#   'Sports Products',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Household items',
#   'F',
#   '26-35'],
#  ['Sports Products', 'F', '26-35'],
#  ['Tupperware', 'Clothing & Apparel', 'M', '18-25'],
#  ['Tupperware', 'Decor', 'F', '18-25'],
#  ['Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Sports Products',
#   'F',
#   '51-55'],
#  ['Furniture',
#   'Furniture',
#   'Footwear & Shoes',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Food',
#   'Games & Toys',
#   'F',
#   '26-35'],
#  ['Food', 'F', '26-35'],
#  ['Food', 'Food', 'M', '51-55'],
#  ['Food', 'Clothing & Apparel', 'M', '18-25'],
#  ['Electronics & Gadgets', 'Games & Toys', 'Beauty', 'M', '55+'],
#  ['Clothing & Apparel', 'F', '55+'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'M',
#   '51-55'],
#  ['Furniture', 'Household items', 'Pet Care', 'F', '18-25'],
#  ['Games & Toys', 'Electronics & Gadgets', 'Clothing & Apparel', 'F', '46-50'],
#  ['Electronics & Gadgets', 'Beauty', 'F', '36-45'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Furniture',
#   'Food',
#   'Clothing & Apparel',
#   'Footwear & Shoes',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'M',
#   '51-55'],
#  ['Food', 'Electronics & Gadgets', 'F', '36-45'],
#  ['Furniture', 'F', '36-45'],
#  ['Furniture',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Food',
#   'Electronics & Gadgets',
#   'Decor',
#   'Electronics & Gadgets',
#   'F',
#   '36-45'],
#  ['Food', 'F', '55+'],
#  ['Food',
#   'Food',
#   'Footwear & Shoes',
#   'Sports Products',
#   'Footwear & Shoes',
#   'Food',
#   'Clothing & Apparel',
#   'Household items',
#   'F',
#   '26-35'],
#  ['Furniture', 'F', '51-55'],
#  ['Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'F',
#   '36-45'],
#  ['Food', 'Clothing & Apparel', 'Clothing & Apparel', 'F', '36-45'],
#  ['Clothing & Apparel', 'Beauty', 'F', '18-25'],
#  ['Food', 'Clothing & Apparel', 'F', '18-25'],
#  ['Footwear & Shoes', 'Food', 'Books', 'F', '36-45'],
#  ['Footwear & Shoes',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Beauty',
#   'M',
#   '51-55'],
#  ['Electronics & Gadgets', 'F', '18-25'],
#  ['Food', 'Food', 'Electronics & Gadgets', 'M', '36-45'],
#  ['Clothing & Apparel', 'M', '26-35'],
#  ['Games & Toys', 'Clothing & Apparel', 'M', '55+'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'M',
#   '0-17'],
#  ['Food', 'Electronics & Gadgets', 'F', '46-50'],
#  ['Clothing & Apparel', 'Food', 'F', '18-25'],
#  ['Food',
#   'Games & Toys',
#   'Food',
#   'Food',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '18-25'],
#  ['Food',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Household items',
#   'Pet Care',
#   'F',
#   '18-25'],
#  ['Food', 'F', '55+'],
#  ['Electronics & Gadgets', 'Clothing & Apparel', 'F', '18-25'],
#  ['Clothing & Apparel', 'F', '26-35'],
#  ['Pet Care', 'F', '36-45'],
#  ['Games & Toys', 'Electronics & Gadgets', 'Food', 'F', '51-55'],
#  ['Food',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'M',
#   '26-35'],
#  ['Electronics & Gadgets', 'F', '36-45'],
#  ['Furniture', 'Electronics & Gadgets', 'M', '18-25'],
#  ['Clothing & Apparel', 'M', '36-45'],
#  ['Household items', 'F', '26-35'],
#  ['Food', 'Clothing & Apparel', 'F', '36-45'],
#  ['Clothing & Apparel', 'Household items', 'F', '26-35'],
#  ['Clothing & Apparel', 'M', '18-25'],
#  ['Stationery', 'Food', 'M', '36-45'],
#  ['Electronics & Gadgets', 'M', '36-45'],
#  ['Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Household items',
#   'M',
#   '36-45'],
#  ['Auto', 'Furniture', 'M', '26-35'],
#  ['Footwear & Shoes',
#   'Food',
#   'Books',
#   'Electronics & Gadgets',
#   'Household items',
#   'Pet Care',
#   'M',
#   '26-35'],
#  ['Furniture', 'Food', 'Food', 'Clothing & Apparel', 'F', '46-50'],
#  ['Food',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Household items',
#   'Electronics & Gadgets',
#   'F',
#   '18-25'],
#  ['Clothing & Apparel', 'F', '36-45'],
#  ['Electronics & Gadgets', 'F', '26-35'],
#  ['Footwear & Shoes', 'F', '36-45'],
#  ['Clothing & Apparel', 'F', '26-35'],
#  ['Food', 'M', '36-45'],
#  ['Sports Products',
#   'Games & Toys',
#   'Electronics & Gadgets',
#   'Beauty',
#   'F',
#   '26-35'],
#  ['Electronics & Gadgets', 'F', '18-25'],
#  ['Clothing & Apparel', 'F', '26-35'],
#  ['Household items', 'M', '26-35'],
#  ['Clothing & Apparel', 'Household items', 'F', '18-25'],
#  ['Clothing & Apparel', 'M', '26-35'],
#  ['Food',
#   'Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Pet Care',
#   'Office',
#   'M',
#   '46-50'],
#  ['Food', 'Food', 'Games & Toys', 'Household items', 'F', '36-45'],
#  ['Food', 'F', '26-35'],
#  ['Food', 'M', '36-45'],
#  ['Auto', 'Books', 'F', '46-50'],
#  ['Electronics & Gadgets', 'M', '26-35'],
#  ['Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Games & Toys',
#   'F',
#   '18-25'],
#  ['Clothing & Apparel', 'F', '36-45'],
#  ['Clothing & Apparel', 'F', '55+'],
#  ['Stationery', 'Electronics & Gadgets', 'M', '18-25'],
#  ['Food',
#   'Food',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Stationery',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Food',
#   'Food',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Household items',
#   'F',
#   '26-35'],
#  ['Footwear & Shoes', 'Household items', 'Household items', 'M', '26-35'],
#  ['Food', 'Electronics & Gadgets', 'Household items', 'F', '18-25'],
#  ['Food', 'Food', 'Electronics & Gadgets', 'F', '18-25'],
#  ['Electronics & Gadgets', 'M', '18-25'],
#  ['Electronics & Gadgets', 'Clothing & Apparel', 'F', '18-25'],
#  ['Clothing & Apparel', 'M', '46-50'],
#  ['Games & Toys', 'F', '26-35'],
#  ['Electronics & Gadgets', 'F', '18-25'],
#  ['Electronics & Gadgets', 'F', '36-45'],
#  ['Tupperware',
#   'Food',
#   'Sports Products',
#   'Sports Products',
#   'Food',
#   'Pet Care',
#   'F',
#   '18-25'],
#  ['Food',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Household items',
#   'F',
#   '26-35'],
#  ['Food', 'F', '26-35'],
#  ['Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '46-50'],
#  ['Furniture', 'M', '51-55'],
#  ['Food', 'Footwear & Shoes', 'F', '55+'],
#  ['Food', 'Household items', 'F', '18-25'],
#  ['Stationery', 'Electronics & Gadgets', 'Games & Toys', 'F', '26-35'],
#  ['Food', 'Footwear & Shoes', 'Electronics & Gadgets', 'F', '36-45'],
#  ['Food', 'Office', 'F', '18-25'],
#  ['Stationery', 'Clothing & Apparel', 'M', '51-55'],
#  ['Clothing & Apparel', 'Clothing & Apparel', 'F', '18-25'],
#  ['Footwear & Shoes', 'F', '26-35'],
#  ['Electronics & Gadgets', 'M', '18-25'],
#  ['Footwear & Shoes',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '26-35'],
#  ['Stationery', 'M', '36-45'],
#  ['Games & Toys', 'Footwear & Shoes', 'F', '36-45'],
#  ['Auto', 'Electronics & Gadgets', 'M', '18-25'],
#  ['Food', 'Electronics & Gadgets', 'Electronics & Gadgets', 'F', '26-35'],
#  ['Food',
#   'Sports Products',
#   'Games & Toys',
#   'Clothing & Apparel',
#   'Household items',
#   'F',
#   '36-45'],
#  ['Electronics & Gadgets', 'F', '36-45'],
#  ['Electronics & Gadgets', 'F', '51-55'],
#  ['Food', 'Electronics & Gadgets', 'Pet Care', 'M', '18-25'],
#  ['Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'F',
#   '46-50'],
#  ['Food',
#   'Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Beauty',
#   'F',
#   '26-35'],
#  ['Footwear & Shoes', 'M', '55+'],
#  ['Sports Products', 'Clothing & Apparel', 'F', '0-17'],
#  ['Footwear & Shoes', 'F', '26-35'],
#  ['Clothing & Apparel', 'F', '51-55'],
#  ['Electronics & Gadgets', 'F', '18-25'],
#  ['Clothing & Apparel', 'Electronics & Gadgets', 'F', '36-45'],
#  ['Electronics & Gadgets', 'M', '18-25'],
#  ['Electronics & Gadgets', 'F', '26-35'],
#  ['Clothing & Apparel', 'F', '26-35'],
#  ['Footwear & Shoes',
#   'Food',
#   'Food',
#   'Food',
#   'Food',
#   'Footwear & Shoes',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Household items',
#   'F',
#   '26-35'],
#  ['Food', 'F', '18-25'],
#  ['Clothing & Apparel', 'M', '46-50'],
#  ['Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'F',
#   '26-35'],
#  ['Clothing & Apparel', 'F', '26-35'],
#  ['Footwear & Shoes',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '26-35'],
#  ['Electronics & Gadgets', 'Electronics & Gadgets', 'M', '26-35'],
#  ['Food', 'Food', 'Electronics & Gadgets', 'M', '36-45'],
#  ['Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'M',
#   '36-45'],
#  ['Footwear & Shoes', 'M', '55+'],
#  ['Furniture', 'Electronics & Gadgets', 'F', '51-55'],
#  ['Furniture',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Beauty',
#   'Pet Care',
#   'F',
#   '18-25'],
#  ['Beauty', 'Office', 'F', '46-50'],
#  ['Clothing & Apparel', 'F', '36-45'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Office',
#   'M',
#   '26-35'],
#  ['Food',
#   'Sports Products',
#   'Food',
#   'Furniture',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Games & Toys',
#   'M',
#   '18-25'],
#  ['Food',
#   'Food',
#   'Food',
#   'Food',
#   'Food',
#   'Food',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'F',
#   '26-35'],
#  ['Food', 'F', '26-35'],
#  ['Games & Toys', 'F', '26-35'],
#  ['Food', 'Food', 'Clothing & Apparel', 'Clothing & Apparel', 'F', '26-35'],
#  ['Food', 'F', '18-25'],
#  ['Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'M',
#   '18-25'],
#  ['Footwear & Shoes',
#   'Food',
#   'Sports Products',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'F',
#   '26-35'],
#  ['Sports Products', 'Sports Products', 'F', '36-45'],
#  ['Clothing & Apparel', 'M', '36-45'],
#  ['Footwear & Shoes',
#   'Furniture',
#   'Food',
#   'Food',
#   'Footwear & Shoes',
#   'Furniture',
#   'Footwear & Shoes',
#   'Food',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Food',
#   'Clothing & Apparel',
#   'F',
#   '26-35'],
#  ['Books',
#   'Footwear & Shoes',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Games & Toys',
#   'Clothing & Apparel',
#   'Beauty',
#   'Electronics & Gadgets',
#   'Food',
#   'F',
#   '46-50'],
#  ['Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'M',
#   '36-45'],
#  ['Food', 'Food', 'F', '51-55'],
#  ['Footwear & Shoes', 'Food', 'F', '26-35'],
#  ['Clothing & Apparel', 'M', '26-35'],
#  ['Clothing & Apparel', 'F', '18-25'],
#  ['Clothing & Apparel', 'Furniture', 'M', '26-35'],
#  ['Footwear & Shoes', 'M', '55+'],
#  ['Clothing & Apparel', 'Clothing & Apparel', 'F', '46-50'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Food',
#   'Clothing & Apparel',
#   'Footwear & Shoes',
#   'Sports Products',
#   'F',
#   '26-35'],
#  ['Electronics & Gadgets', 'F', '26-35'],
#  ['Games & Toys',
#   'Games & Toys',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '26-35'],
#  ['Footwear & Shoes', 'F', '36-45'],
#  ['Food', 'M', '18-25'],
#  ['Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Household items',
#   'F',
#   '26-35'],
#  ['Electronics & Gadgets', 'Clothing & Apparel', 'F', '51-55'],
#  ['Food', 'M', '36-45'],
#  ['Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Food',
#   'Veterinary',
#   'F',
#   '26-35'],
#  ['Games & Toys', 'M', '46-50'],
#  ['Household items', 'M', '36-45'],
#  ['Furniture', 'Food', 'F', '26-35'],
#  ['Games & Toys', 'Clothing & Apparel', 'M', '0-17'],
#  ['Furniture',
#   'Food',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'M',
#   '26-35'],
#  ['Electronics & Gadgets', 'M', '26-35'],
#  ['Electronics & Gadgets', 'M', '18-25'],
#  ['Games & Toys', 'F', '36-45'],
#  ['Auto', 'Food', 'Clothing & Apparel', 'Beauty', 'F', '26-35'],
#  ['Auto',
#   'Auto',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'M',
#   '26-35'],
#  ['Games & Toys', 'Beauty', 'Pet Care', 'Household items', 'M', '36-45'],
#  ['Food', 'Sports Products', 'Games & Toys', 'F', '26-35'],
#  ['Clothing & Apparel', 'M', '51-55'],
#  ['Clothing & Apparel', 'M', '55+'],
#  ['Food', 'Clothing & Apparel', 'F', '26-35'],
#  ['Food',
#   'Furniture',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'M',
#   '18-25'],
#  ['Sports Products', 'M', '55+'],
#  ['Games & Toys', 'M', '26-35'],
#  ['Footwear & Shoes',
#   'Furniture',
#   'Food',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'F',
#   '46-50'],
#  ['Footwear & Shoes', 'M', '18-25'],
#  ['Household items', 'F', '26-35'],
#  ['Hand & Power Tools', 'F', '18-25'],
#  ['Footwear & Shoes', 'M', '26-35'],
#  ['Food', 'Beauty', 'F', '26-35'],
#  ['Tupperware', 'Food', 'Clothing & Apparel', 'Pet Care', 'F', '36-45'],
#  ['Clothing & Apparel', 'F', '51-55'],
#  ['Food', 'F', '36-45'],
#  ['Food', 'Food', 'F', '26-35'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Food',
#   'Games & Toys',
#   'F',
#   '26-35'],
#  ['Footwear & Shoes',
#   'Food',
#   'Furniture',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'F',
#   '26-35'],
#  ['Food', 'Electronics & Gadgets', 'M', '36-45'],
#  ['Furniture', 'Clothing & Apparel', 'F', '18-25'],
#  ['Food', 'Furniture', 'M', '36-45'],
#  ['Food', 'Food', 'M', '36-45'],
#  ['Food', 'F', '36-45'],
#  ['Food', 'F', '26-35'],
#  ['Clothing & Apparel', 'F', '0-17'],
#  ['Clothing & Apparel', 'F', '55+'],
#  ['Clothing & Apparel', 'F', '18-25'],
#  ['Furniture',
#   'Food',
#   'Hand & Power Tools',
#   'Food',
#   'Food',
#   'Clothing & Apparel',
#   'Beauty',
#   'M',
#   '36-45'],
#  ['Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'F',
#   '46-50'],
#  ['Footwear & Shoes',
#   'Household items',
#   'Electronics & Gadgets',
#   'F',
#   '26-35'],
#  ['Footwear & Shoes',
#   'Food',
#   'Food',
#   'Footwear & Shoes',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'M',
#   '36-45'],
#  ['Food', 'Food', 'F', '36-45'],
#  ['Clothing & Apparel', 'Household items', 'M', '26-35'],
#  ['Furniture',
#   'Footwear & Shoes',
#   'Food',
#   'Games & Toys',
#   'Food',
#   'Food',
#   'Household items',
#   'M',
#   '36-45'],
#  ['Food',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'F',
#   '51-55'],
#  ['Food',
#   'Food',
#   'Decor',
#   'Electronics & Gadgets',
#   'Decor',
#   'Electronics & Gadgets',
#   'Household items',
#   'Pet Care',
#   'M',
#   '26-35'],
#  ['Clothing & Apparel', 'M', '46-50'],
#  ['Food', 'Clothing & Apparel', 'Electronics & Gadgets', 'M', '26-35'],
#  ['Food', 'Beauty', 'M', '26-35'],
#  ['Furniture', 'Electronics & Gadgets', 'F', '18-25'],
#  ['Food', 'Footwear & Shoes', 'Food', 'Electronics & Gadgets', 'F', '36-45'],
#  ['Auto',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '26-35'],
#  ['Food',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Household items',
#   'Beauty',
#   'F',
#   '26-35'],
#  ['Footwear & Shoes', 'F', '26-35'],
#  ['Clothing & Apparel', 'F', '26-35'],
#  ['Household items', 'M', '26-35'],
#  ['Footwear & Shoes', 'F', '26-35'],
#  ['Food', 'Food', 'Food', 'F', '18-25'],
#  ['Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'F',
#   '51-55'],
#  ['Footwear & Shoes',
#   'Food',
#   'Food',
#   'Food',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Food',
#   'Clothing & Apparel',
#   'F',
#   '26-35'],
#  ['Electronics & Gadgets', 'F', '36-45'],
#  ['Veterinary', 'F', '26-35'],
#  ['Auto',
#   'Tupperware',
#   'Food',
#   'Electronics & Gadgets',
#   'Books',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Office',
#   'Office',
#   'M',
#   '26-35'],
#  ['Household items', 'Clothing & Apparel', 'Clothing & Apparel', 'M', '51-55'],
#  ['Food', 'Pet Care', 'F', '26-35'],
#  ['Food', 'Clothing & Apparel', 'M', '26-35'],
#  ['Footwear & Shoes', 'F', '36-45'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Office',
#   'M',
#   '18-25'],
#  ['Electronics & Gadgets', 'M', '51-55'],
#  ['Food', 'F', '18-25'],
#  ['Clothing & Apparel', 'M', '18-25'],
#  ['Hand & Power Tools', 'Food', 'Food', 'Household items', 'M', '36-45'],
#  ['Food', 'M', '36-45'],
#  ['Food', 'Footwear & Shoes', 'Food', 'Clothing & Apparel', 'F', '36-45'],
#  ['Clothing & Apparel', 'F', '18-25'],
#  ['Footwear & Shoes',
#   'Furniture',
#   'Food',
#   'Sports Products',
#   'Beauty',
#   'Food',
#   'Household items',
#   'F',
#   '26-35'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'M',
#   '26-35'],
#  ['Food', 'Electronics & Gadgets', 'Household items', 'F', '26-35'],
#  ['Footwear & Shoes', 'Household items', 'F', '36-45'],
#  ['Food', 'Food', 'Clothing & Apparel', 'M', '18-25'],
#  ['Food', 'Games & Toys', 'F', '18-25'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Footwear & Shoes',
#   'F',
#   '18-25'],
#  ['Books',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'M',
#   '36-45'],
#  ['Food', 'Food', 'Tupperware', 'F', '26-35'],
#  ['Footwear & Shoes', 'Footwear & Shoes', 'Footwear & Shoes', 'F', '51-55'],
#  ['Food', 'Clothing & Apparel', 'F', '55+'],
#  ['Food', 'Office', 'M', '26-35'],
#  ['Food', 'Clothing & Apparel', 'Clothing & Apparel', 'F', '36-45'],
#  ['Auto', 'Footwear & Shoes', 'Beauty', 'Sports Products', 'F', '26-35'],
#  ['Footwear & Shoes', 'F', '36-45'],
#  ['Sports Products', 'F', '26-35'],
#  ['Footwear & Shoes',
#   'Games & Toys',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '46-50'],
#  ['Auto', 'Food', 'Games & Toys', 'F', '26-35'],
#  ['Footwear & Shoes', 'Food', 'Electronics & Gadgets', 'F', '36-45'],
#  ['Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Household items',
#   'Clothing & Apparel',
#   'F',
#   '26-35'],
#  ['Electronics & Gadgets', 'Clothing & Apparel', 'F', '18-25'],
#  ['Food', 'Clothing & Apparel', 'Beauty', 'M', '0-17'],
#  ['Food', 'M', '18-25'],
#  ['Food', 'Clothing & Apparel', 'F', '26-35'],
#  ['Food', 'F', '26-35'],
#  ['Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'F',
#   '0-17'],
#  ['Footwear & Shoes', 'Food', 'Beauty', 'M', '26-35'],
#  ['Clothing & Apparel', 'F', '0-17'],
#  ['Food',
#   'Food',
#   'Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Household items',
#   'Electronics & Gadgets',
#   'M',
#   '18-25'],
#  ['Clothing & Apparel', 'F', '18-25'],
#  ['Clothing & Apparel', 'F', '26-35'],
#  ['Footwear & Shoes',
#   'Food',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Books',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'F',
#   '36-45'],
#  ['Games & Toys', 'M', '36-45'],
#  ['Food',
#   'Food',
#   'Footwear & Shoes',
#   'Food',
#   'Games & Toys',
#   'Clothing & Apparel',
#   'Food',
#   'Electronics & Gadgets',
#   'Food',
#   'Clothing & Apparel',
#   'M',
#   '26-35'],
#  ['Sports Products',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'F',
#   '0-17'],
#  ['Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '36-45'],
#  ['Food',
#   'Games & Toys',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'F',
#   '26-35'],
#  ['Footwear & Shoes', 'Pet Care', 'F', '36-45'],
#  ['Clothing & Apparel', 'M', '55+'],
#  ['Pet Care', 'F', '55+'],
#  ['Food', 'F', '18-25'],
#  ['Food', 'F', '0-17'],
#  ['Food', 'Furniture', 'Food', 'Household items', 'F', '26-35'],
#  ['Footwear & Shoes', 'Food', 'Electronics & Gadgets', 'F', '26-35'],
#  ['Games & Toys',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '18-25'],
#  ['Food', 'Electronics & Gadgets', 'Electronics & Gadgets', 'F', '18-25'],
#  ['Furniture',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Household items',
#   'Beauty',
#   'Household items',
#   'M',
#   '18-25'],
#  ['Sports Products', 'F', '18-25'],
#  ['Food',
#   'Furniture',
#   'Clothing & Apparel',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Food',
#   'F',
#   '26-35'],
#  ['Furniture', 'Food', 'F', '26-35'],
#  ['Beauty', 'F', '18-25'],
#  ['Footwear & Shoes', 'F', '26-35'],
#  ['Food', 'Sports Products', 'Pet Care', 'F', '18-25'],
#  ['Sports Products', 'Clothing & Apparel', 'F', '26-35'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Beauty',
#   'Clothing & Apparel',
#   'M',
#   '36-45'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'F',
#   '26-35'],
#  ['Furniture',
#   'Food',
#   'Electronics & Gadgets',
#   'Household items',
#   'M',
#   '36-45'],
#  ['Food',
#   'Tupperware',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '51-55'],
#  ['Clothing & Apparel', 'M', '51-55'],
#  ['Food', 'Clothing & Apparel', 'Clothing & Apparel', 'M', '26-35'],
#  ['Electronics & Gadgets', 'M', '26-35'],
#  ['Food',
#   'Sports Products',
#   'Food',
#   'Food',
#   'Clothing & Apparel',
#   'Beauty',
#   'Office',
#   'F',
#   '26-35'],
#  ['Clothing & Apparel', 'F', '18-25'],
#  ['Food', 'Electronics & Gadgets', 'F', '26-35'],
#  ['Food', 'F', '26-35'],
#  ['Auto', 'Food', 'F', '18-25'],
#  ['Pet Care', 'M', '18-25'],
#  ['Footwear & Shoes',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '46-50'],
#  ['Clothing & Apparel', 'F', '18-25'],
#  ['Clothing & Apparel', 'F', '18-25'],
#  ['Food', 'F', '36-45'],
#  ['Games & Toys',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'M',
#   '26-35'],
#  ['Food', 'Clothing & Apparel', 'F', '26-35'],
#  ['Food', 'Beauty', 'F', '36-45'],
#  ['Electronics & Gadgets', 'F', '46-50'],
#  ['Games & Toys', 'Electronics & Gadgets', 'M', '0-17'],
#  ['Food', 'F', '18-25'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Beauty',
#   'M',
#   '51-55'],
#  ['Footwear & Shoes',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Pet Care',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '26-35'],
#  ['Food', 'Household items', 'M', '26-35'],
#  ['Clothing & Apparel', 'M', '18-25'],
#  ['Food', 'Household items', 'F', '26-35'],
#  ['Veterinary', 'F', '26-35'],
#  ['Clothing & Apparel', 'Electronics & Gadgets', 'M', '18-25'],
#  ['Beauty', 'Clothing & Apparel', 'F', '26-35'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Furniture',
#   'Food',
#   'Games & Toys',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'F',
#   '36-45'],
#  ['Food', 'Food', 'Food', 'Clothing & Apparel', 'F', '18-25'],
#  ['Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '26-35'],
#  ['Furniture',
#   'Furniture',
#   'Furniture',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Pet Care',
#   'Pet Care',
#   'M',
#   '26-35'],
#  ['Footwear & Shoes',
#   'Furniture',
#   'Electronics & Gadgets',
#   'Books',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Household items',
#   'Pet Care',
#   'M',
#   '18-25'],
#  ['Electronics & Gadgets', 'F', '36-45'],
#  ['Food', 'Tupperware', 'F', '36-45'],
#  ['Food', 'Electronics & Gadgets', 'Electronics & Gadgets', 'F', '26-35'],
#  ['Sports Products', 'Clothing & Apparel', 'F', '26-35'],
#  ['Pet Care', 'F', '26-35'],
#  ['Clothing & Apparel', 'Household items', 'M', '26-35'],
#  ['Furniture', 'Footwear & Shoes', 'F', '36-45'],
#  ['Food', 'F', '0-17'],
#  ['Clothing & Apparel', 'F', '46-50'],
#  ['Food',
#   'Auto',
#   'Food',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Household items',
#   'Office',
#   'F',
#   '18-25'],
#  ['Electronics & Gadgets', 'F', '0-17'],
#  ['Footwear & Shoes', 'Electronics & Gadgets', 'F', '51-55'],
#  ['Beauty', 'F', '55+'],
#  ['Food', 'F', '26-35'],
#  ['Food',
#   'Food',
#   'Food',
#   'Furniture',
#   'Food',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Household items',
#   'Household items',
#   'Veterinary',
#   'F',
#   '26-35'],
#  ['Sports Products', 'F', '18-25'],
#  ['Food',
#   'Food',
#   'Food',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Household items',
#   'F',
#   '18-25'],
#  ['Games & Toys', 'M', '36-45'],
#  ['Food', 'Food', 'M', '0-17'],
#  ['Furniture', 'Electronics & Gadgets', 'F', '36-45'],
#  ['Food', 'F', '0-17'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Food',
#   'Footwear & Shoes',
#   'Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'F',
#   '46-50'],
#  ['Food', 'Food', 'F', '26-35'],
#  ['Food', 'F', '26-35'],
#  ['Electronics & Gadgets', 'F', '26-35'],
#  ['Food', 'Clothing & Apparel', 'Electronics & Gadgets', 'M', '26-35'],
#  ['Auto', 'M', '55+'],
#  ['Food', 'Beauty', 'F', '36-45'],
#  ['Electronics & Gadgets', 'M', '46-50'],
#  ['Electronics & Gadgets', 'M', '51-55'],
#  ['Food',
#   'Food',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Beauty',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'F',
#   '51-55'],
#  ['Food', 'Sports Products', 'M', '46-50'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Household items',
#   'M',
#   '36-45'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Food',
#   'Clothing & Apparel',
#   'M',
#   '55+'],
#  ['Footwear & Shoes', 'Clothing & Apparel', 'F', '51-55'],
#  ['Electronics & Gadgets', 'M', '36-45'],
#  ['Clothing & Apparel', 'F', '0-17'],
#  ['Clothing & Apparel', 'M', '26-35'],
#  ['Food', 'M', '55+'],
#  ['Games & Toys',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Household items',
#   'F',
#   '26-35'],
#  ['Food', 'F', '26-35'],
#  ['Electronics & Gadgets', 'M', '55+'],
#  ['Food',
#   'Food',
#   'Food',
#   'Games & Toys',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'M',
#   '36-45'],
#  ['Food', 'F', '18-25'],
#  ['Footwear & Shoes', 'F', '26-35'],
#  ['Food', 'Clothing & Apparel', 'M', '26-35'],
#  ['Electronics & Gadgets', 'Electronics & Gadgets', 'F', '0-17'],
#  ['Furniture', 'Electronics & Gadgets', 'M', '51-55'],
#  ['Food', 'Clothing & Apparel', 'Clothing & Apparel', 'F', '46-50'],
#  ['Footwear & Shoes', 'Food', 'F', '36-45'],
#  ['Electronics & Gadgets', 'Electronics & Gadgets', 'F', '18-25'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '51-55'],
#  ['Food', 'Clothing & Apparel', 'F', '36-45'],
#  ['Food', 'F', '46-50'],
#  ['Electronics & Gadgets', 'Footwear & Shoes', 'F', '55+'],
#  ['Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Beauty',
#   'F',
#   '51-55'],
#  ['Food', 'Household items', 'Clothing & Apparel', 'M', '51-55'],
#  ['Food', 'Auto', 'Footwear & Shoes', 'F', '36-45'],
#  ['Food',
#   'Games & Toys',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Decor',
#   'Clothing & Apparel',
#   'Pet Care',
#   'Clothing & Apparel',
#   'F',
#   '36-45'],
#  ['Games & Toys', 'F', '51-55'],
#  ['Food', 'Clothing & Apparel', 'F', '18-25'],
#  ['Food',
#   'Food',
#   'Stationery',
#   'Clothing & Apparel',
#   'Beauty',
#   'Beauty',
#   'Veterinary',
#   'F',
#   '26-35'],
#  ['Food', 'Electronics & Gadgets', 'F', '55+'],
#  ['Games & Toys', 'Clothing & Apparel', 'F', '51-55'],
#  ['Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Furniture',
#   'Food',
#   'Household items',
#   'F',
#   '26-35'],
#  ['Footwear & Shoes', 'Stationery', 'Pet Care', 'F', '26-35'],
#  ['Food', 'M', '26-35'],
#  ['Clothing & Apparel', 'F', '36-45'],
#  ['Furniture',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Food',
#   'Clothing & Apparel',
#   'F',
#   '36-45'],
#  ['Footwear & Shoes', 'F', '36-45'],
#  ['Clothing & Apparel', 'F', '26-35'],
#  ['Clothing & Apparel', 'F', '0-17'],
#  ['Beauty', 'F', '26-35'],
#  ['Books', 'Electronics & Gadgets', 'Electronics & Gadgets', 'M', '26-35'],
#  ['Tupperware',
#   'Food',
#   'Footwear & Shoes',
#   'Food',
#   'Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Beauty',
#   'F',
#   '51-55'],
#  ['Clothing & Apparel', 'F', '26-35'],
#  ['Clothing & Apparel', 'M', '26-35'],
#  ['Stationery',
#   'Furniture',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'F',
#   '26-35'],
#  ['Food', 'Sports Products', 'F', '46-50'],
#  ['Electronics & Gadgets', 'Household items', 'Veterinary', 'F', '26-35'],
#  ['Footwear & Shoes',
#   'Food',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Household items',
#   'M',
#   '26-35'],
#  ['Furniture', 'F', '18-25'],
#  ['Clothing & Apparel', 'F', '36-45'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Food',
#   'Food',
#   'Sports Products',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Games & Toys',
#   'F',
#   '26-35'],
#  ['Food', 'F', '26-35'],
#  ['Stationery',
#   'Footwear & Shoes',
#   'Food',
#   'Food',
#   'Games & Toys',
#   'Stationery',
#   'Food',
#   'Sports Products',
#   'Stationery',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'F',
#   '36-45'],
#  ['Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Beauty',
#   'F',
#   '55+'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Electronics & Gadgets',
#   'F',
#   '36-45'],
#  ['Food', 'Clothing & Apparel', 'Office', 'F', '18-25'],
#  ['Footwear & Shoes',
#   'Food',
#   'Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Beauty',
#   'F',
#   '36-45'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'F',
#   '36-45'],
#  ['Food', 'Electronics & Gadgets', 'F', '26-35'],
#  ['Games & Toys', 'Food', 'F', '55+'],
#  ['Clothing & Apparel', 'M', '36-45'],
#  ['Food', 'Household items', 'F', '26-35'],
#  ['Clothing & Apparel', 'M', '46-50'],
#  ['Sports Products', 'Electronics & Gadgets', 'Food', 'F', '18-25'],
#  ['Footwear & Shoes',
#   'Food',
#   'Games & Toys',
#   'Clothing & Apparel',
#   'F',
#   '26-35'],
#  ['Footwear & Shoes', 'F', '26-35'],
#  ['Food', 'Electronics & Gadgets', 'Office', 'F', '51-55'],
#  ['Food', 'Beauty', 'Clothing & Apparel', 'F', '26-35'],
#  ['Electronics & Gadgets', 'F', '18-25'],
#  ['Games & Toys', 'F', '36-45'],
#  ['Food', 'F', '46-50'],
#  ['Electronics & Gadgets', 'M', '55+'],
#  ['Food',
#   'Books',
#   'Food',
#   'Electronics & Gadgets',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Food',
#   'F',
#   '26-35'],
#  ['Footwear & Shoes', 'Beauty', 'F', '46-50'],
#  ['Food', 'F', '26-35'],
#  ['Clothing & Apparel', 'F', '46-50'],
#  ['Footwear & Shoes',
#   'Food',
#   'Sports Products',
#   'Food',
#   'Beauty',
#   'Electronics & Gadgets',
#   'Food',
#   'F',
#   '26-35'],
#  ['Auto',
#   'Food',
#   'Food',
#   'Furniture',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Household items',
#   'M',
#   '26-35'],
#  ['Footwear & Shoes', 'Clothing & Apparel', 'Office', 'F', '36-45'],
#  ['Food', 'Household items', 'F', '0-17'],
#  ['Food', 'Footwear & Shoes', 'F', '46-50'],
#  ['Furniture', 'Clothing & Apparel', 'Clothing & Apparel', 'F', '26-35'],
#  ['Furniture',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'M',
#   '26-35'],
#  ['Food', 'F', '46-50'],
#  ['Clothing & Apparel', 'F', '51-55'],
#  ['Electronics & Gadgets', 'Clothing & Apparel', 'F', '36-45'],
#  ['Clothing & Apparel', 'Household items', 'M', '26-35'],
#  ['Food', 'Clothing & Apparel', 'F', '36-45'],
#  ['Books',
#   'Decor',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Books',
#   'Household items',
#   'M',
#   '18-25'],
#  ['Food',
#   'Food',
#   'Food',
#   'Food',
#   'Games & Toys',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Electronics & Gadgets',
#   'Veterinary',
#   'Veterinary',
#   'F',
#   '26-35'],
#  ['Electronics & Gadgets', 'M', '46-50'],
#  ['Food', 'M', '36-45'],
#  ['Electronics & Gadgets', 'M', '26-35'],
#  ['Food', 'Beauty', 'Pet Care', 'Beauty', 'F', '46-50'],
#  ['Food', 'M', '26-35'],
#  ['Sports Products', 'Books', 'M', '26-35'],
#  ['Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Footwear & Shoes',
#   'Household items',
#   'Beauty',
#   'F',
#   '26-35'],
#  ['Food', 'Clothing & Apparel', 'M', '46-50'],
#  ['Clothing & Apparel', 'F', '55+'],
#  ['Clothing & Apparel', 'M', '0-17'],
#  ['Food', 'F', '26-35'],
#  ['Games & Toys', 'Electronics & Gadgets', 'F', '18-25'],
#  ['Footwear & Shoes',
#   'Games & Toys',
#   'Clothing & Apparel',
#   'Beauty',
#   'Clothing & Apparel',
#   'Beauty',
#   'F',
#   '26-35'],
#  ['Furniture',
#   'Furniture',
#   'Food',
#   'Sports Products',
#   'Footwear & Shoes',
#   'Food',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Office',
#   'F',
#   '0-17'],
#  ['Electronics & Gadgets', 'M', '18-25'],
#  ['Beauty', 'F', '51-55'],
#  ['Electronics & Gadgets', 'M', '18-25'],
#  ['Furniture', 'Sports Products', 'Food', 'F', '0-17'],
#  ['Electronics & Gadgets',
#   'Food',
#   'Clothing & Apparel',
#   'Food',
#   'Household items',
#   'F',
#   '26-35'],
#  ['Games & Toys',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Veterinary',
#   'F',
#   '26-35'],
#  ['Auto',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Hand & Power Tools',
#   'F',
#   '36-45'],
#  ['Tupperware', 'M', '46-50'],
#  ['Electronics & Gadgets', 'M', '51-55'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Food',
# ...
#   'F',
#   '26-35'],
#  ['Clothing & Apparel', 'F', '26-35'],
#  ['Clothing & Apparel', 'M', '51-55'],
#  ['Games & Toys',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Pet Care',
#   'M',
#   '46-50'],
#  ['Beauty', 'F', '18-25'],
#  ['Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Beauty',
#   'F',
#   '36-45'],
#  ['Footwear & Shoes',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Beauty',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Food',
#   'Clothing & Apparel',
#   'F',
#   '46-50'],
#  ['Clothing & Apparel', 'F', '36-45'],
#  ['Food', 'Household items', 'F', '18-25'],
#  ['Footwear & Shoes',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '36-45'],
#  ['Food', 'F', '0-17'],
#  ['Food',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '26-35'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Books',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Food',
#   'M',
#   '46-50'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Food',
#   'Food',
#   'Footwear & Shoes',
#   'Sports Products',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Games & Toys',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Food',
#   'Clothing & Apparel',
#   'M',
#   '36-45'],
#  ['Pet Care', 'M', '51-55'],
#  ['Food', 'Furniture', 'Electronics & Gadgets', 'M', '36-45'],
#  ['Food', 'Clothing & Apparel', 'M', '36-45'],
#  ['Beauty', 'F', '26-35'],
#  ['Food', 'Electronics & Gadgets', 'M', '51-55'],
#  ['Food', 'Clothing & Apparel', 'F', '0-17'],
#  ['Furniture', 'F', '26-35'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Games & Toys',
#   'Food',
#   'Games & Toys',
#   'Furniture',
#   'Furniture',
#   'Food',
#   'Games & Toys',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Food',
#   'Clothing & Apparel',
#   'F',
#   '36-45'],
#  ['Stationery', 'Footwear & Shoes', 'Electronics & Gadgets', 'M', '26-35'],
#  ['Electronics & Gadgets',
#   'Games & Toys',
#   'Electronics & Gadgets',
#   'Decor',
#   'Clothing & Apparel',
#   'M',
#   '0-17'],
#  ['Food',
#   'Clothing & Apparel',
#   'Beauty',
#   'Beauty',
#   'Household items',
#   'Household items',
#   'Clothing & Apparel',
#   'M',
#   '26-35'],
#  ['Pet Care', 'F', '18-25'],
#  ['Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Household items',
#   'Household items',
#   'F',
#   '26-35'],
#  ['Electronics & Gadgets', 'F', '26-35'],
#  ['Food',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Veterinary',
#   'F',
#   '26-35'],
#  ['Clothing & Apparel', 'F', '55+'],
#  ['Footwear & Shoes', 'F', '26-35'],
#  ['Food', 'F', '46-50'],
#  ['Pet Care', 'F', '18-25'],
#  ['Food', 'Auto', 'Footwear & Shoes', 'Beauty', 'F', '26-35'],
#  ['Clothing & Apparel', 'F', '18-25'],
#  ['Food', 'Clothing & Apparel', 'Electronics & Gadgets', 'M', '18-25'],
#  ['Food',
#   'Footwear & Shoes',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'F',
#   '46-50'],
#  ['Household items', 'F', '26-35'],
#  ['Furniture', 'Clothing & Apparel', 'M', '26-35'],
#  ['Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'F',
#   '55+'],
#  ['Food', 'Clothing & Apparel', 'M', '36-45'],
#  ['Sports Products', 'F', '36-45'],
#  ['Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Footwear & Shoes',
#   'F',
#   '26-35'],
#  ['Beauty', 'F', '36-45'],
#  ['Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Household items',
#   'F',
#   '18-25'],
#  ['Footwear & Shoes',
#   'Food',
#   'Food',
#   'Games & Toys',
#   'Clothing & Apparel',
#   'F',
#   '46-50'],
#  ['Furniture', 'F', '26-35'],
#  ['Games & Toys',
#   'Clothing & Apparel',
#   'Household items',
#   'Household items',
#   'Clothing & Apparel',
#   'F',
#   '26-35'],
#  ['Footwear & Shoes',
#   'Food',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '36-45'],
#  ['Clothing & Apparel', 'Electronics & Gadgets', 'F', '26-35'],
#  ['Footwear & Shoes', 'Furniture', 'Clothing & Apparel', 'F', '36-45'],
#  ['Clothing & Apparel', 'Clothing & Apparel', 'F', '26-35'],
#  ['Footwear & Shoes', 'Books', 'Clothing & Apparel', 'F', '36-45'],
#  ['Games & Toys', 'Clothing & Apparel', 'M', '18-25'],
#  ['Electronics & Gadgets', 'Clothing & Apparel', 'M', '36-45'],
#  ['Household items', 'M', '26-35'],
#  ['Footwear & Shoes', 'Clothing & Apparel', 'F', '36-45'],
#  ['Footwear & Shoes',
#   'Food',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Household items',
#   'M',
#   '26-35'],
#  ['Food', 'M', '46-50'],
#  ['Food',
#   'Games & Toys',
#   'Beauty',
#   'Clothing & Apparel',
#   'Household items',
#   'M',
#   '18-25'],
#  ['Footwear & Shoes', 'Footwear & Shoes', 'Food', 'Pet Care', 'F', '46-50'],
#  ['Furniture', 'Food', 'Clothing & Apparel', 'Beauty', 'F', '36-45'],
#  ['Footwear & Shoes',
#   'Food',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'M',
#   '36-45'],
#  ['Food', 'Food', 'Office', 'F', '26-35'],
#  ['Food', 'M', '26-35'],
#  ['Sports Products',
#   'Clothing & Apparel',
#   'Stationery',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'F',
#   '36-45'],
#  ['Electronics & Gadgets', 'M', '46-50'],
#  ['Food', 'Food', 'M', '0-17'],
#  ['Food', 'Clothing & Apparel', 'Household items', 'Pet Care', 'F', '0-17'],
#  ['Furniture',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Household items',
#   'F',
#   '26-35'],
#  ['Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Household items',
#   'F',
#   '26-35'],
#  ['Food', 'F', '0-17'],
#  ['Electronics & Gadgets', 'M', '26-35'],
#  ['Food', 'Pet Care', 'M', '46-50'],
#  ['Food',
#   'Clothing & Apparel',
#   'Games & Toys',
#   'Household items',
#   'F',
#   '36-45'],
#  ['Clothing & Apparel', 'F', '0-17'],
#  ['Stationery', 'F', '18-25'],
#  ['Auto',
#   'Food',
#   'Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Furniture',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Footwear & Shoes',
#   'Beauty',
#   'Beauty',
#   'Electronics & Gadgets',
#   'M',
#   '26-35'],
#  ['Food', 'Books', 'F', '18-25'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'M',
#   '51-55'],
#  ['Stationery', 'Electronics & Gadgets', 'F', '26-35'],
#  ['Food',
#   'Footwear & Shoes',
#   'Stationery',
#   'Clothing & Apparel',
#   'Pet Care',
#   'F',
#   '36-45'],
#  ['Footwear & Shoes', 'Food', 'Clothing & Apparel', 'Office', 'F', '46-50'],
#  ['Furniture', 'F', '18-25'],
#  ['Footwear & Shoes',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Household items',
#   'F',
#   '26-35'],
#  ['Electronics & Gadgets', 'Footwear & Shoes', 'M', '26-35'],
#  ['Furniture', 'F', '36-45'],
#  ['Games & Toys', 'M', '55+'],
#  ['Food', 'F', '18-25'],
#  ['Pet Care', 'M', '18-25'],
#  ['Auto',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Furniture',
#   'F',
#   '51-55'],
#  ['Footwear & Shoes', 'F', '26-35'],
#  ['Games & Toys', 'Clothing & Apparel', 'Household items', 'M', '36-45'],
#  ['Electronics & Gadgets', 'Food', 'Veterinary', 'F', '51-55'],
#  ['Food', 'F', '26-35'],
#  ['Furniture',
#   'Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Household items',
#   'F',
#   '18-25'],
#  ['Food', 'Electronics & Gadgets', 'F', '18-25'],
#  ['Sports Products', 'Clothing & Apparel', 'F', '46-50'],
#  ['Tupperware',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'F',
#   '18-25'],
#  ['Footwear & Shoes',
#   'Decor',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'F',
#   '18-25'],
#  ['Furniture', 'F', '0-17'],
#  ['Food',
#   'Food',
#   'Footwear & Shoes',
#   'Decor',
#   'Clothing & Apparel',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Food',
#   'Household items',
#   'F',
#   '36-45'],
#  ['Footwear & Shoes', 'F', '26-35'],
#  ['Pet Care', 'F', '36-45'],
#  ['Auto',
#   'Food',
#   'Food',
#   'Games & Toys',
#   'Clothing & Apparel',
#   'Food',
#   'Beauty',
#   'Clothing & Apparel',
#   'Household items',
#   'Household items',
#   'Veterinary',
#   'M',
#   '0-17'],
#  ['Food',
#   'Food',
#   'Food',
#   'Food',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'F',
#   '18-25'],
#  ['Food', 'F', '26-35'],
#  ['Food', 'Food', 'Electronics & Gadgets', 'F', '18-25'],
#  ['Games & Toys',
#   'Food',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '0-17'],
#  ['Food', 'M', '51-55'],
#  ['Food', 'Clothing & Apparel', 'F', '51-55'],
#  ['Electronics & Gadgets', 'F', '18-25'],
#  ['Electronics & Gadgets', 'F', '36-45'],
#  ['Tupperware',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Household items',
#   'F',
#   '36-45'],
#  ['Clothing & Apparel', 'F', '36-45'],
#  ['Stationery',
#   'Food',
#   'Sports Products',
#   'Electronics & Gadgets',
#   'M',
#   '18-25'],
#  ['Food', 'Clothing & Apparel', 'M', '26-35'],
#  ['Electronics & Gadgets', 'F', '36-45'],
#  ['Stationery',
#   'Food',
#   'Food',
#   'Food',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Household items',
#   'M',
#   '18-25'],
#  ['Food',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Stationery',
#   'Food',
#   'Household items',
#   'M',
#   '26-35'],
#  ['Food',
#   'Footwear & Shoes',
#   'Books',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '36-45'],
#  ['Furniture',
#   'Footwear & Shoes',
#   'Food',
#   'Footwear & Shoes',
#   'Games & Toys',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Games & Toys',
#   'Pet Care',
#   'M',
#   '36-45'],
#  ['Electronics & Gadgets', 'F', '18-25'],
#  ['Footwear & Shoes', 'Tupperware', 'M', '26-35'],
#  ['Footwear & Shoes',
#   'Food',
#   'Footwear & Shoes',
#   'Food',
#   'Pet Care',
#   'F',
#   '26-35'],
#  ['Electronics & Gadgets', 'M', '26-35'],
#  ['Electronics & Gadgets', 'M', '46-50'],
#  ['Food', 'F', '51-55'],
#  ['Food',
#   'Food',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'F',
#   '51-55'],
#  ['Sports Products',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Beauty',
#   'F',
#   '18-25'],
#  ['Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'M',
#   '0-17'],
#  ['Food', 'Auto', 'Clothing & Apparel', 'Electronics & Gadgets', 'F', '18-25'],
#  ['Decor', 'F', '26-35'],
#  ['Food', 'Food', 'Clothing & Apparel', 'Household items', 'F', '26-35'],
#  ['Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Food',
#   'Pet Care',
#   'F',
#   '26-35'],
#  ['Food', 'M', '26-35'],
#  ['Food', 'Clothing & Apparel', 'M', '18-25'],
#  ['Clothing & Apparel', 'F', '26-35'],
#  ['Electronics & Gadgets', 'Electronics & Gadgets', 'F', '26-35'],
#  ['Food',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'F',
#   '18-25'],
#  ['Clothing & Apparel', 'Clothing & Apparel', 'M', '26-35'],
#  ['Food', 'Electronics & Gadgets', 'F', '36-45'],
#  ['Electronics & Gadgets',
#   'Household items',
#   'Clothing & Apparel',
#   'M',
#   '36-45'],
#  ['Furniture',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'M',
#   '51-55'],
#  ['Hand & Power Tools', 'Games & Toys', 'Electronics & Gadgets', 'M', '18-25'],
#  ['Footwear & Shoes', 'Books', 'Clothing & Apparel', 'F', '26-35'],
#  ['Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Household items',
#   'F',
#   '26-35'],
#  ['Stationery',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Household items',
#   'F',
#   '18-25'],
#  ['Footwear & Shoes',
#   'Food',
#   'Footwear & Shoes',
#   'Food',
#   'Food',
#   'Decor',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Pet Care',
#   'Office',
#   'F',
#   '26-35'],
#  ['Electronics & Gadgets', 'F', '18-25'],
#  ['Furniture', 'Food', 'F', '0-17'],
#  ['Footwear & Shoes',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '26-35'],
#  ['Furniture', 'Food', 'Clothing & Apparel', 'Stationery', 'F', '26-35'],
#  ['Games & Toys', 'Food', 'Food', 'F', '18-25'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Furniture',
#   'Furniture',
#   'Games & Toys',
#   'Food',
#   'M',
#   '26-35'],
#  ['Auto',
#   'Footwear & Shoes',
#   'Pet Care',
#   'Pet Care',
#   'Electronics & Gadgets',
#   'F',
#   '51-55'],
#  ['Footwear & Shoes', 'F', '26-35'],
#  ['Electronics & Gadgets', 'F', '36-45'],
#  ['Electronics & Gadgets', 'Household items', 'Household items', 'M', '0-17'],
#  ['Household items', 'M', '26-35'],
#  ['Food', 'F', '36-45'],
#  ['Pet Care', 'F', '26-35'],
#  ['Furniture', 'Electronics & Gadgets', 'M', '36-45'],
#  ['Food', 'Sports Products', 'Clothing & Apparel', 'F', '18-25'],
#  ['Household items', 'M', '26-35'],
#  ['Footwear & Shoes', 'F', '26-35'],
#  ['Food', 'Clothing & Apparel', 'F', '36-45'],
#  ['Footwear & Shoes', 'Pet Care', 'F', '26-35'],
#  ['Decor', 'Electronics & Gadgets', 'F', '18-25'],
#  ['Food', 'M', '26-35'],
#  ['Food', 'F', '55+'],
#  ['Clothing & Apparel', 'F', '18-25'],
#  ['Food', 'Electronics & Gadgets', 'F', '26-35'],
#  ['Food', 'Food', 'Clothing & Apparel', 'F', '26-35'],
#  ['Food', 'F', '46-50'],
#  ['Food', 'F', '18-25'],
#  ['Electronics & Gadgets', 'F', '46-50'],
#  ['Sports Products', 'F', '46-50'],
#  ['Food', 'F', '55+'],
#  ['Office', 'F', '18-25'],
#  ['Food', 'Clothing & Apparel', 'F', '26-35'],
#  ['Footwear & Shoes', 'F', '26-35'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'F',
#   '26-35'],
#  ['Furniture', 'Clothing & Apparel', 'Sports Products', 'F', '26-35'],
#  ['Food', 'F', '36-45'],
#  ['Clothing & Apparel', 'F', '36-45'],
#  ['Sports Products', 'F', '18-25'],
#  ['Food', 'F', '26-35'],
#  ['Food',
#   'Beauty',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '46-50'],
#  ['Food', 'Food', 'Clothing & Apparel', 'Food', 'F', '18-25'],
#  ['Food', 'Clothing & Apparel', 'M', '18-25'],
#  ['Electronics & Gadgets', 'F', '36-45'],
#  ['Furniture', 'M', '18-25'],
#  ['Food', 'Clothing & Apparel', 'Clothing & Apparel', 'M', '0-17'],
#  ['Food', 'Clothing & Apparel', 'F', '51-55'],
#  ['Electronics & Gadgets', 'Games & Toys', 'F', '26-35'],
#  ['Auto', 'F', '26-35'],
#  ['Food', 'F', '26-35'],
#  ['Food', 'Household items', 'M', '51-55'],
#  ['Electronics & Gadgets', 'M', '55+'],
#  ['Food',
#   'Sports Products',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Food',
#   'Household items',
#   'Veterinary',
#   'F',
#   '26-35'],
#  ['Clothing & Apparel',
#   'Clothing & Apparel',
#   'Beauty',
#   'Footwear & Shoes',
#   'Furniture',
#   'F',
#   '26-35'],
#  ['Clothing & Apparel', 'F', '55+'],
#  ['Sports Products',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'F',
#   '46-50'],
#  ['Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Pet Care',
#   'M',
#   '26-35'],
#  ['Footwear & Shoes',
#   'Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'F',
#   '51-55'],
#  ['Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'M',
#   '36-45'],
#  ['Footwear & Shoes', 'Games & Toys', 'Food', 'Household items', 'F', '26-35'],
#  ['Food', 'M', '36-45'],
#  ['Pet Care', 'F', '36-45'],
#  ['Clothing & Apparel', 'Beauty', 'F', '36-45'],
#  ['Furniture',
#   'Footwear & Shoes',
#   'Games & Toys',
#   'Clothing & Apparel',
#   'Beauty',
#   'Footwear & Shoes',
#   'Pet Care',
#   'Household items',
#   'F',
#   '26-35'],
#  ['Food', 'Clothing & Apparel', 'F', '36-45'],
#  ['Clothing & Apparel', 'Clothing & Apparel', 'Veterinary', 'F', '26-35'],
#  ...]

# %%
# Transform data
te = TransactionEncoder()
transactions = te.fit(data).transform(data) # or fit_transform(data)

# Create a dataframe from the data
df_encoded = pd.DataFrame(transactions, columns=te.columns_)
df_encoded
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        0-17  18-25  26-35  36-45  46-50  51-55    55+   Auto  Beauty  Books  \
# 0      True  False  False  False  False  False  False  False   False  False
# 1     False  False  False  False  False  False   True  False   False  False
# 2     False  False   True  False  False  False  False  False   False  False
# 3     False  False  False  False   True  False  False  False   False  False
# 4     False  False   True  False  False  False  False  False   False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...     ...    ...
# 3750  False  False   True  False  False  False  False  False   False  False
# 3751  False  False   True  False  False  False  False  False    True  False
# 3752  False  False  False  False   True  False  False  False   False  False
# 3753  False  False  False  False   True  False  False  False   False  False
# 3754  False  False   True  False  False  False  False  False   False  False
#
#       ...  Games & Toys  Hand & Power Tools  Household items      M  Office  \
# 0     ...         False               False            False  False   False
# 1     ...         False               False            False  False   False
# 2     ...         False               False            False  False   False
# 3     ...         False               False            False  False   False
# 4     ...         False               False            False  False   False
# ...   ...           ...                 ...              ...    ...     ...
# 3750  ...         False               False            False   True   False
# 3751  ...          True               False            False   True   False
# 3752  ...         False               False            False   True   False
# 3753  ...         False               False             True   True   False
# 3754  ...          True               False            False  False   False
#
#       Pet Care  Sports Products  Stationery  Tupperware  Veterinary
# 0        False            False       False       False       False
# 1        False            False       False       False       False
# 2        False            False       False       False       False
# 3        False            False       False       False       False
# 4        False             True       False       False       False
# ...        ...              ...         ...         ...         ...
# 3750     False            False       False       False       False
# 3751     False             True       False       False       False
# 3752     False            False       False       False       False
# 3753     False            False       False       False       False
# 3754     False             True       False       False       False
#
# [3755 rows x 27 columns]

# %%
frequent_itemsets = apriori(df_encoded, min_support=0.05, use_colnames=True)
frequent_itemsets.sort_values(by="support")
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      support                                  itemsets
# 43  0.050333        (Games & Toys, Clothing & Apparel)
# 49  0.050333  (Electronics & Gadgets, Household items)
# 60  0.050333                      (M, Household items)
# 71  0.050866                          (M, 26-35, Food)
# 85  0.051398          (M, Electronics & Gadgets, Food)
# ..       ...                                       ...
# 1   0.369374                                   (26-35)
# 8   0.375499                   (Electronics & Gadgets)
# 10  0.452730                                    (Food)
# 7   0.467909                      (Clothing & Apparel)
# 9   0.668176                                       (F)
#
# [90 rows x 2 columns]

# %%
rules = association_rules(frequent_itemsets, num_itemsets=frequent_itemsets.shape[0], metric="support", min_threshold=0.05)
rules = rules[rules["lift"] > 1] # Only recommend products that are of more interest to the demographic than the general population
rules = rules[rules["antecedents"].apply(lambda x: {"26-35", "F"} == set(x) )] # Specify the demographic
rules = rules[rules["consequents"].apply(lambda x: len(x) == 1 )] # Recommend single product categories.

rules.sort_values(by=["lift", "confidence"])
rules
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     antecedents              consequents  antecedent support  \
# 104  (26-35, F)     (Clothing & Apparel)            0.256458
# 124  (26-35, F)  (Electronics & Gadgets)            0.256458
# 134  (26-35, F)                   (Food)            0.256458
# 140  (26-35, F)       (Footwear & Shoes)            0.256458
#
#      consequent support   support  confidence      lift  representativity  \
# 104            0.467909  0.124900    0.487020  1.040842               1.0
# 124            0.375499  0.099068    0.386293  1.028744               1.0
# 134            0.452730  0.119840    0.467290  1.032161               1.0
# 140            0.213316  0.073502    0.286604  1.343570               1.0
#
#      leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 104  0.004901    1.037253       0.052773  0.208352   0.035915    0.376976
# 124  0.002768    1.017587       0.037579  0.185907   0.017283    0.325061
# 134  0.003734    1.027332       0.041905  0.203344   0.026605    0.365998
# 140  0.018795    1.102732       0.343914  0.185484   0.093162    0.315587

# %% [markdown]
# For a female customer aged 25-35, without knowing anything about her past purchase pattern, recommending the consequents above would be sensible as her demographics would be more interested in these categories than the general population.

# %% [markdown]
# # Question 3 **(5 Points)**

# %% [markdown]
# Your company plans to open a branch near a **bank** and wants to cater to **banking customers** based on transaction data.
#
#
# > Find a product category that is **at least 20% more likely** to be purchased by **bankers** compared to the **average population**.
#
# This will help the company **strategically stock products** that appeal most to banking customers.

# %%
# To solve this, we need to encode all of product categories and gender.

basket = df.groupby('User_ID')[['Product_Category', 'Occupation']]
basket = basket.agg({
    'Product_Category': lambda x: ','.join(map(str, x)),
    'Occupation': 'first',
}).reset_index()
basket
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       User_ID                                   Product_Category  \
# 0     1000001                              Electronics & Gadgets
# 1     1000002                                 Clothing & Apparel
# 2     1000003                              Footwear & Shoes,Food
# 3     1000004                             Footwear & Shoes,Decor
# 4     1000005                   Footwear & Shoes,Sports Products
# ...       ...                                                ...
# 3750  1006035  Clothing & Apparel,Clothing & Apparel,Clothing...
# 3751  1006036  Food,Food,Food,Games & Toys,Food,Electronics &...
# 3752  1006037                            Food,Clothing & Apparel
# 3753  1006039  Electronics & Gadgets,Clothing & Apparel,House...
# 3754  1006040  Footwear & Shoes,Footwear & Shoes,Sports Produ...
#
#            Occupation
# 0            Aviation
# 1         Agriculture
# 2          Automobile
# 3              Retail
# 4     Food Processing
# ...               ...
# 3750       Healthcare
# 3751         Chemical
# 3752        IT Sector
# 3753      Hospitality
# 3754        IT Sector
#
# [3755 rows x 3 columns]

# %%
# Preparing data format
data = list(basket.apply(lambda x: x['Product_Category'].split(',') + [x['Occupation']], axis=1))
data
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [['Electronics & Gadgets', 'Aviation'],
#  ['Clothing & Apparel', 'Agriculture'],
#  ['Footwear & Shoes', 'Food', 'Automobile'],
#  ['Footwear & Shoes', 'Decor', 'Retail'],
#  ['Footwear & Shoes', 'Sports Products', 'Food Processing'],
#  ['Food', 'Electronics & Gadgets', 'Media'],
#  ['Footwear & Shoes',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Food Processing'],
#  ['Footwear & Shoes', 'Household items', 'Food Processing'],
#  ['Food',
#   'Furniture',
#   'Clothing & Apparel',
#   'Games & Toys',
#   'Beauty',
#   'Chemical'],
#  ['Food', 'Electronics & Gadgets', 'Clothing & Apparel', 'IT Sector'],
#  ['Food', 'Clothing & Apparel', 'Chemical'],
#  ['Sports Products', 'Retail'],
#  ['Footwear & Shoes', 'Games & Toys', 'Banking'],
#  ['Clothing & Apparel', 'Furniture', 'Media'],
#  ['Food', 'Clothing & Apparel', 'Aviation'],
#  ['Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'IT Sector'],
#  ['Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Household items',
#   'Hospitality'],
#  ['Games & Toys', 'Food', 'Textile'],
#  ['Food',
#   'Furniture',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Clothing & Apparel',
#   'Aviation'],
#  ['Clothing & Apparel', 'Media'],
#  ['Games & Toys', 'Aviation'],
#  ['Food', 'Food', 'Healthcare'],
#  ['Clothing & Apparel', 'Food Processing'],
#  ['Furniture',
#   'Sports Products',
#   'Food',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Food',
#   'Games & Toys',
#   'Clothing & Apparel',
#   'Banking'],
#  ['Food', 'Banking'],
#  ['Food', 'Decor', 'Banking'],
#  ['Furniture',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Construction'],
#  ['Clothing & Apparel', 'Lawyer'],
#  ['Furniture', 'Household items', 'IT Sector'],
#  ['Footwear & Shoes', 'Media'],
#  ['Beauty',
#   'Clothing & Apparel',
#   'Stationery',
#   'Household items',
#   'Veterinary',
#   'Govt'],
#  ['Electronics & Gadgets', 'Electronics & Gadgets', 'Beauty', 'IT Sector'],
#  ['Food', 'Media'],
#  ['Footwear & Shoes',
#   'Auto',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Office',
#   'Aviation'],
#  ['Food', 'Retail'],
#  ['Footwear & Shoes', 'Footwear & Shoes', 'Household items', 'Retail'],
#  ['Electronics & Gadgets', 'Govt'],
#  ['Household items', 'Construction'],
#  ['Food',
#   'Food',
#   'Books',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Office',
#   'Chemical'],
#  ['Clothing & Apparel', 'Construction'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Household items',
#   'Construction'],
#  ['Food', 'Decor', 'Clothing & Apparel', 'Food Processing'],
#  ['Furniture', 'Clothing & Apparel', 'Chemical'],
#  ['Footwear & Shoes', 'Retail'],
#  ['Furniture', 'Games & Toys', 'Clothing & Apparel', 'Govt'],
#  ['Electronics & Gadgets', 'Food Processing'],
#  ['Clothing & Apparel', 'Agriculture'],
#  ['Sports Products', 'Clothing & Apparel', 'Food', 'Automobile'],
#  ['Food', 'Clothing & Apparel', 'Govt'],
#  ['Food', 'Food Processing'],
#  ['Food', 'Clothing & Apparel', 'IT Sector'],
#  ['Clothing & Apparel', 'Clothing & Apparel', 'Beauty', 'IT Sector'],
#  ['Clothing & Apparel', 'Clothing & Apparel', 'Automobile'],
#  ['Electronics & Gadgets', 'Aviation'],
#  ['Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Automobile'],
#  ['Footwear & Shoes', 'IT Sector'],
#  ['Furniture', 'Food', 'Food', 'Clothing & Apparel', 'Lawyer'],
#  ['Food', 'Clothing & Apparel', 'Media'],
#  ['Electronics & Gadgets', 'Electronics & Gadgets', 'Agriculture'],
#  ['Food', 'Automobile'],
#  ['Electronics & Gadgets', 'IT Sector'],
#  ['Food', 'Furniture', 'Food', 'Govt'],
#  ['Sports Products', 'Aviation'],
#  ['Sports Products', 'Construction'],
#  ['Electronics & Gadgets', 'Media'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Sports Products',
#   'Lawyer'],
#  ['Clothing & Apparel', 'Clothing & Apparel', 'Govt'],
#  ['Clothing & Apparel', 'IT Sector'],
#  ['Electronics & Gadgets', 'Veterinary', 'Automobile'],
#  ['Electronics & Gadgets', 'Lawyer'],
#  ['Auto', 'Govt'],
#  ['Electronics & Gadgets', 'Agriculture'],
#  ['Food', 'Furniture', 'Books', 'Decor', 'Clothing & Apparel', 'Chemical'],
#  ['Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Household items',
#   'IT Sector'],
#  ['Electronics & Gadgets', 'Healthcare'],
#  ['Auto', 'Govt'],
#  ['Footwear & Shoes',
#   'Food',
#   'Food',
#   'Sports Products',
#   'Food',
#   'Decor',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Chemical'],
#  ['Footwear & Shoes', 'Hospitality'],
#  ['Electronics & Gadgets', 'Govt'],
#  ['Clothing & Apparel', 'IT Sector'],
#  ['Pet Care', 'Pet Care', 'Retail'],
#  ['Sports Products', 'Media'],
#  ['Food',
#   'Food',
#   'Sports Products',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Healthcare'],
#  ['Clothing & Apparel', 'Retail'],
#  ['Games & Toys',
#   'Games & Toys',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Food',
#   'Retail'],
#  ['Food',
#   'Sports Products',
#   'Food',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Beauty',
#   'Clothing & Apparel',
#   'Chemical'],
#  ['Footwear & Shoes', 'Games & Toys', 'Automobile'],
#  ['Electronics & Gadgets', 'IT Sector'],
#  ['Household items', 'Food Processing'],
#  ['Games & Toys', 'Clothing & Apparel', 'Food Processing'],
#  ['Electronics & Gadgets', 'Agriculture'],
#  ['Food', 'Clothing & Apparel', 'Household items', 'Hospitality'],
#  ['Electronics & Gadgets', 'Healthcare'],
#  ['Furniture',
#   'Food',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Pet Care',
#   'Pet Care',
#   'Office',
#   'Banking'],
#  ['Food',
#   'Clothing & Apparel',
#   'Household items',
#   'Beauty',
#   'Pet Care',
#   'Banking'],
#  ['Food', 'Electronics & Gadgets', 'Pet Care', 'Agriculture'],
#  ['Stationery',
#   'Tupperware',
#   'Food',
#   'Food',
#   'Food',
#   'Books',
#   'Electronics & Gadgets',
#   'IT Sector'],
#  ['Food', 'IT Sector'],
#  ['Footwear & Shoes', 'Textile'],
#  ['Food', 'Electronics & Gadgets', 'IT Sector'],
#  ['Clothing & Apparel', 'Electronics & Gadgets', 'Healthcare'],
#  ['Footwear & Shoes',
#   'Furniture',
#   'Food',
#   'Footwear & Shoes',
#   'Books',
#   'Auto',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Automobile'],
#  ['Footwear & Shoes',
#   'Food',
#   'Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'IT Sector'],
#  ['Clothing & Apparel', 'Agriculture'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Banking'],
#  ['Clothing & Apparel', 'Beauty', 'Media'],
#  ['Furniture', 'Food Processing'],
#  ['Food', 'Chemical'],
#  ['Food',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Healthcare'],
#  ['Tupperware',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Banking'],
#  ['Beauty', 'IT Sector'],
#  ['Sports Products', 'Clothing & Apparel', 'Lawyer'],
#  ['Clothing & Apparel', 'IT Sector'],
#  ['Stationery', 'IT Sector'],
#  ['Stationery', 'Clothing & Apparel', 'Household items', 'Aviation'],
#  ['Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'IT Sector'],
#  ['Food', 'Clothing & Apparel', 'Agriculture'],
#  ['Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Aviation'],
#  ['Clothing & Apparel', 'Pet Care', 'IT Sector'],
#  ['Food', 'Food Processing'],
#  ['Electronics & Gadgets', 'Chemical'],
#  ['Food', 'Healthcare'],
#  ['Auto',
#   'Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Food',
#   'Food',
#   'Govt'],
#  ['Footwear & Shoes', 'Electronics & Gadgets', 'Office', 'Media'],
#  ['Food', 'Sports Products', 'Banking'],
#  ['Sports Products', 'Textile'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Veterinary',
#   'IT Sector'],
#  ['Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Household items',
#   'Healthcare'],
#  ['Footwear & Shoes',
#   'Games & Toys',
#   'Games & Toys',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Govt'],
#  ['Furniture', 'Govt'],
#  ['Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Automobile'],
#  ['Pet Care', 'Healthcare'],
#  ['Electronics & Gadgets', 'Books', 'Textile'],
#  ['Food', 'Food', 'Clothing & Apparel', 'Food', 'Construction'],
#  ['Food', 'Footwear & Shoes', 'Electronics & Gadgets', 'Chemical'],
#  ['Electronics & Gadgets', 'Food', 'Banking'],
#  ['Clothing & Apparel', 'Hospitality'],
#  ['Food', 'Chemical'],
#  ['Electronics & Gadgets', 'Electronics & Gadgets', 'Aviation'],
#  ['Auto', 'Healthcare'],
#  ['Furniture', 'Electronics & Gadgets', 'Books', 'Hospitality'],
#  ['Auto',
#   'Sports Products',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Retail'],
#  ['Office', 'Banking'],
#  ['Footwear & Shoes',
#   'Food',
#   'Food',
#   'Sports Products',
#   'Books',
#   'Electronics & Gadgets',
#   'Furniture',
#   'Food',
#   'Clothing & Apparel',
#   'Decor',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Aviation'],
#  ['Food', 'Clothing & Apparel', 'Clothing & Apparel', 'Media'],
#  ['Clothing & Apparel', 'Clothing & Apparel', 'Pet Care', 'Chemical'],
#  ['Food', 'Food', 'Electronics & Gadgets', 'IT Sector'],
#  ['Furniture',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Lawyer'],
#  ['Footwear & Shoes', 'Clothing & Apparel', 'Food Processing'],
#  ['Household items', 'IT Sector'],
#  ['Clothing & Apparel', 'Lawyer'],
#  ['Footwear & Shoes',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Pet Care',
#   'Banking'],
#  ['Clothing & Apparel', 'Hospitality'],
#  ['Electronics & Gadgets', 'Healthcare'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Games & Toys',
#   'Clothing & Apparel',
#   'Veterinary',
#   'Chemical'],
#  ['Food', 'Govt'],
#  ['Clothing & Apparel', 'Beauty', 'Pet Care', 'Healthcare'],
#  ['Food',
#   'Sports Products',
#   'Electronics & Gadgets',
#   'Office',
#   'Office',
#   'Healthcare'],
#  ['Clothing & Apparel', 'Chemical'],
#  ['Footwear & Shoes',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Games & Toys',
#   'Clothing & Apparel',
#   'Beauty',
#   'Pet Care',
#   'Banking'],
#  ['Sports Products', 'Healthcare'],
#  ['Food', 'Aviation'],
#  ['Beauty', 'IT Sector'],
#  ['Electronics & Gadgets', 'Beauty', 'Clothing & Apparel', 'Govt'],
#  ['Food', 'Electronics & Gadgets', 'Healthcare'],
#  ['Electronics & Gadgets', 'Clothing & Apparel', 'Aviation'],
#  ['Food', 'Healthcare'],
#  ['Clothing & Apparel', 'Aviation'],
#  ['Household items', 'Automobile'],
#  ['Furniture',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Automobile'],
#  ['Electronics & Gadgets', 'Clothing & Apparel', 'Agriculture'],
#  ['Food', 'Lawyer'],
#  ['Food',
#   'Food',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Food',
#   'Sports Products',
#   'Electronics & Gadgets',
#   'Food',
#   'Electronics & Gadgets',
#   'Aviation'],
#  ['Food', 'Automobile'],
#  ['Food', 'Food', 'Clothing & Apparel', 'Govt'],
#  ['Electronics & Gadgets', 'Clothing & Apparel', 'Banking'],
#  ['Furniture',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Beauty',
#   'Food',
#   'Veterinary',
#   'Retail'],
#  ['Food',
#   'Food',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'IT Sector'],
#  ['Electronics & Gadgets', 'Automobile'],
#  ['Clothing & Apparel', 'Media'],
#  ['Electronics & Gadgets', 'Banking'],
#  ['Food', 'Furniture', 'Food Processing'],
#  ['Footwear & Shoes', 'Electronics & Gadgets', 'Hospitality'],
#  ['Furniture', 'Clothing & Apparel', 'Household items', 'Lawyer'],
#  ['Footwear & Shoes',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Beauty',
#   'Healthcare'],
#  ['Sports Products', 'Clothing & Apparel', 'Lawyer'],
#  ['Food', 'Furniture', 'Retail'],
#  ['Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Aviation'],
#  ['Food', 'Decor', 'Electronics & Gadgets', 'Healthcare'],
#  ['Electronics & Gadgets', 'Lawyer'],
#  ['Food', 'Banking'],
#  ['Tupperware', 'Chemical'],
#  ['Electronics & Gadgets', 'Clothing & Apparel', 'Media'],
#  ['Electronics & Gadgets', 'Clothing & Apparel', 'Textile'],
#  ['Food',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Household items',
#   'Electronics & Gadgets',
#   'Decor',
#   'Healthcare'],
#  ['Food',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Clothing & Apparel',
#   'Retail'],
#  ['Food',
#   'Sports Products',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Household items',
#   'IT Sector'],
#  ['Sports Products', 'Automobile'],
#  ['Tupperware', 'Clothing & Apparel', 'Aviation'],
#  ['Tupperware', 'Decor', 'Aviation'],
#  ['Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Sports Products',
#   'Automobile'],
#  ['Furniture',
#   'Furniture',
#   'Footwear & Shoes',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Food',
#   'Games & Toys',
#   'Hospitality'],
#  ['Food', 'Media'],
#  ['Food', 'Food', 'Aviation'],
#  ['Food', 'Clothing & Apparel', 'Healthcare'],
#  ['Electronics & Gadgets', 'Games & Toys', 'Beauty', 'Govt'],
#  ['Clothing & Apparel', 'Media'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Aviation'],
#  ['Furniture', 'Household items', 'Pet Care', 'Automobile'],
#  ['Games & Toys', 'Electronics & Gadgets', 'Clothing & Apparel', 'IT Sector'],
#  ['Electronics & Gadgets', 'Beauty', 'Govt'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Furniture',
#   'Food',
#   'Clothing & Apparel',
#   'Footwear & Shoes',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'IT Sector'],
#  ['Food', 'Electronics & Gadgets', 'Retail'],
#  ['Furniture', 'Textile'],
#  ['Furniture',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Food',
#   'Electronics & Gadgets',
#   'Decor',
#   'Electronics & Gadgets',
#   'Chemical'],
#  ['Food', 'Govt'],
#  ['Food',
#   'Food',
#   'Footwear & Shoes',
#   'Sports Products',
#   'Footwear & Shoes',
#   'Food',
#   'Clothing & Apparel',
#   'Household items',
#   'Textile'],
#  ['Furniture', 'Aviation'],
#  ['Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Govt'],
#  ['Food', 'Clothing & Apparel', 'Clothing & Apparel', 'IT Sector'],
#  ['Clothing & Apparel', 'Beauty', 'Food Processing'],
#  ['Food', 'Clothing & Apparel', 'IT Sector'],
#  ['Footwear & Shoes', 'Food', 'Books', 'Automobile'],
#  ['Footwear & Shoes',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Beauty',
#   'IT Sector'],
#  ['Electronics & Gadgets', 'Chemical'],
#  ['Food', 'Food', 'Electronics & Gadgets', 'Chemical'],
#  ['Clothing & Apparel', 'Food Processing'],
#  ['Games & Toys', 'Clothing & Apparel', 'Textile'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Healthcare'],
#  ['Food', 'Electronics & Gadgets', 'Retail'],
#  ['Clothing & Apparel', 'Food', 'Construction'],
#  ['Food',
#   'Games & Toys',
#   'Food',
#   'Food',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Lawyer'],
#  ['Food',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Household items',
#   'Pet Care',
#   'IT Sector'],
#  ['Food', 'Chemical'],
#  ['Electronics & Gadgets', 'Clothing & Apparel', 'Automobile'],
#  ['Clothing & Apparel', 'Govt'],
#  ['Pet Care', 'Chemical'],
#  ['Games & Toys', 'Electronics & Gadgets', 'Food', 'Govt'],
#  ['Food',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Media'],
#  ['Electronics & Gadgets', 'Hospitality'],
#  ['Furniture', 'Electronics & Gadgets', 'Govt'],
#  ['Clothing & Apparel', 'Banking'],
#  ['Household items', 'Aviation'],
#  ['Food', 'Clothing & Apparel', 'Aviation'],
#  ['Clothing & Apparel', 'Household items', 'Hospitality'],
#  ['Clothing & Apparel', 'Agriculture'],
#  ['Stationery', 'Food', 'Healthcare'],
#  ['Electronics & Gadgets', 'Automobile'],
#  ['Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Household items',
#   'Healthcare'],
#  ['Auto', 'Furniture', 'Food Processing'],
#  ['Footwear & Shoes',
#   'Food',
#   'Books',
#   'Electronics & Gadgets',
#   'Household items',
#   'Pet Care',
#   'Automobile'],
#  ['Furniture', 'Food', 'Food', 'Clothing & Apparel', 'Automobile'],
#  ['Food',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Household items',
#   'Electronics & Gadgets',
#   'Healthcare'],
#  ['Clothing & Apparel', 'Govt'],
#  ['Electronics & Gadgets', 'Construction'],
#  ['Footwear & Shoes', 'IT Sector'],
#  ['Clothing & Apparel', 'Govt'],
#  ['Food', 'IT Sector'],
#  ['Sports Products',
#   'Games & Toys',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Govt'],
#  ['Electronics & Gadgets', 'Banking'],
#  ['Clothing & Apparel', 'Govt'],
#  ['Household items', 'Aviation'],
#  ['Clothing & Apparel', 'Household items', 'Textile'],
#  ['Clothing & Apparel', 'Construction'],
#  ['Food',
#   'Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Pet Care',
#   'Office',
#   'Media'],
#  ['Food', 'Food', 'Games & Toys', 'Household items', 'Media'],
#  ['Food', 'Banking'],
#  ['Food', 'Agriculture'],
#  ['Auto', 'Books', 'Banking'],
#  ['Electronics & Gadgets', 'Construction'],
#  ['Electronics & Gadgets', 'Electronics & Gadgets', 'Games & Toys', 'Govt'],
#  ['Clothing & Apparel', 'Banking'],
#  ['Clothing & Apparel', 'Aviation'],
#  ['Stationery', 'Electronics & Gadgets', 'Automobile'],
#  ['Food',
#   'Food',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Stationery',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Food',
#   'Food',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Household items',
#   'Aviation'],
#  ['Footwear & Shoes', 'Household items', 'Household items', 'IT Sector'],
#  ['Food', 'Electronics & Gadgets', 'Household items', 'Hospitality'],
#  ['Food', 'Food', 'Electronics & Gadgets', 'Healthcare'],
#  ['Electronics & Gadgets', 'Automobile'],
#  ['Electronics & Gadgets', 'Clothing & Apparel', 'Automobile'],
#  ['Clothing & Apparel', 'Retail'],
#  ['Games & Toys', 'Healthcare'],
#  ['Electronics & Gadgets', 'Automobile'],
#  ['Electronics & Gadgets', 'IT Sector'],
#  ['Tupperware',
#   'Food',
#   'Sports Products',
#   'Sports Products',
#   'Food',
#   'Pet Care',
#   'IT Sector'],
#  ['Food',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Household items',
#   'Govt'],
#  ['Food', 'Agriculture'],
#  ['Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Retail'],
#  ['Furniture', 'Hospitality'],
#  ['Food', 'Footwear & Shoes', 'Healthcare'],
#  ['Food', 'Household items', 'Retail'],
#  ['Stationery', 'Electronics & Gadgets', 'Games & Toys', 'Lawyer'],
#  ['Food', 'Footwear & Shoes', 'Electronics & Gadgets', 'Food Processing'],
#  ['Food', 'Office', 'Govt'],
#  ['Stationery', 'Clothing & Apparel', 'Healthcare'],
#  ['Clothing & Apparel', 'Clothing & Apparel', 'Automobile'],
#  ['Footwear & Shoes', 'IT Sector'],
#  ['Electronics & Gadgets', 'Healthcare'],
#  ['Footwear & Shoes', 'Clothing & Apparel', 'Clothing & Apparel', 'Media'],
#  ['Stationery', 'Textile'],
#  ['Games & Toys', 'Footwear & Shoes', 'Food Processing'],
#  ['Auto', 'Electronics & Gadgets', 'Govt'],
#  ['Food', 'Electronics & Gadgets', 'Electronics & Gadgets', 'Aviation'],
#  ['Food',
#   'Sports Products',
#   'Games & Toys',
#   'Clothing & Apparel',
#   'Household items',
#   'Agriculture'],
#  ['Electronics & Gadgets', 'Banking'],
#  ['Electronics & Gadgets', 'IT Sector'],
#  ['Food', 'Electronics & Gadgets', 'Pet Care', 'IT Sector'],
#  ['Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Food Processing'],
#  ['Food',
#   'Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Beauty',
#   'Aviation'],
#  ['Footwear & Shoes', 'Healthcare'],
#  ['Sports Products', 'Clothing & Apparel', 'Hospitality'],
#  ['Footwear & Shoes', 'Govt'],
#  ['Clothing & Apparel', 'Textile'],
#  ['Electronics & Gadgets', 'Govt'],
#  ['Clothing & Apparel', 'Electronics & Gadgets', 'IT Sector'],
#  ['Electronics & Gadgets', 'IT Sector'],
#  ['Electronics & Gadgets', 'IT Sector'],
#  ['Clothing & Apparel', 'Automobile'],
#  ['Footwear & Shoes',
#   'Food',
#   'Food',
#   'Food',
#   'Food',
#   'Footwear & Shoes',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Household items',
#   'Banking'],
#  ['Food', 'IT Sector'],
#  ['Clothing & Apparel', 'Healthcare'],
#  ['Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Banking'],
#  ['Clothing & Apparel', 'Banking'],
#  ['Footwear & Shoes',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'IT Sector'],
#  ['Electronics & Gadgets', 'Electronics & Gadgets', 'Hospitality'],
#  ['Food', 'Food', 'Electronics & Gadgets', 'Govt'],
#  ['Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'IT Sector'],
#  ['Footwear & Shoes', 'Food Processing'],
#  ['Furniture', 'Electronics & Gadgets', 'Healthcare'],
#  ['Furniture',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Beauty',
#   'Pet Care',
#   'IT Sector'],
#  ['Beauty', 'Office', 'Automobile'],
#  ['Clothing & Apparel', 'Aviation'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Office',
#   'Aviation'],
#  ['Food',
#   'Sports Products',
#   'Food',
#   'Furniture',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Games & Toys',
#   'Healthcare'],
#  ['Food',
#   'Food',
#   'Food',
#   'Food',
#   'Food',
#   'Food',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Aviation'],
#  ['Food', 'IT Sector'],
#  ['Games & Toys', 'Construction'],
#  ['Food', 'Food', 'Clothing & Apparel', 'Clothing & Apparel', 'Media'],
#  ['Food', 'Govt'],
#  ['Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Banking'],
#  ['Footwear & Shoes',
#   'Food',
#   'Sports Products',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'IT Sector'],
#  ['Sports Products', 'Sports Products', 'Healthcare'],
#  ['Clothing & Apparel', 'Aviation'],
#  ['Footwear & Shoes',
#   'Furniture',
#   'Food',
#   'Food',
#   'Footwear & Shoes',
#   'Furniture',
#   'Footwear & Shoes',
#   'Food',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Food',
#   'Clothing & Apparel',
#   'IT Sector'],
#  ['Books',
#   'Footwear & Shoes',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Games & Toys',
#   'Clothing & Apparel',
#   'Beauty',
#   'Electronics & Gadgets',
#   'Food',
#   'Banking'],
#  ['Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Healthcare'],
#  ['Food', 'Food', 'IT Sector'],
#  ['Footwear & Shoes', 'Food', 'Aviation'],
#  ['Clothing & Apparel', 'Healthcare'],
#  ['Clothing & Apparel', 'Textile'],
#  ['Clothing & Apparel', 'Furniture', 'Healthcare'],
#  ['Footwear & Shoes', 'Aviation'],
#  ['Clothing & Apparel', 'Clothing & Apparel', 'Automobile'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Food',
#   'Clothing & Apparel',
#   'Footwear & Shoes',
#   'Sports Products',
#   'Healthcare'],
#  ['Electronics & Gadgets', 'Agriculture'],
#  ['Games & Toys',
#   'Games & Toys',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Banking'],
#  ['Footwear & Shoes', 'Healthcare'],
#  ['Food', 'Banking'],
#  ['Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Household items',
#   'IT Sector'],
#  ['Electronics & Gadgets', 'Clothing & Apparel', 'Construction'],
#  ['Food', 'Aviation'],
#  ['Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Food',
#   'Veterinary',
#   'Healthcare'],
#  ['Games & Toys', 'IT Sector'],
#  ['Household items', 'Textile'],
#  ['Furniture', 'Food', 'Automobile'],
#  ['Games & Toys', 'Clothing & Apparel', 'Banking'],
#  ['Furniture',
#   'Food',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Aviation'],
#  ['Electronics & Gadgets', 'IT Sector'],
#  ['Electronics & Gadgets', 'Textile'],
#  ['Games & Toys', 'Banking'],
#  ['Auto', 'Food', 'Clothing & Apparel', 'Beauty', 'Lawyer'],
#  ['Auto',
#   'Auto',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Food Processing'],
#  ['Games & Toys', 'Beauty', 'Pet Care', 'Household items', 'Aviation'],
#  ['Food', 'Sports Products', 'Games & Toys', 'IT Sector'],
#  ['Clothing & Apparel', 'Banking'],
#  ['Clothing & Apparel', 'Banking'],
#  ['Food', 'Clothing & Apparel', 'Aviation'],
#  ['Food',
#   'Furniture',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Aviation'],
#  ['Sports Products', 'Retail'],
#  ['Games & Toys', 'IT Sector'],
#  ['Footwear & Shoes',
#   'Furniture',
#   'Food',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Healthcare'],
#  ['Footwear & Shoes', 'Aviation'],
#  ['Household items', 'Hospitality'],
#  ['Hand & Power Tools', 'Hospitality'],
#  ['Footwear & Shoes', 'Agriculture'],
#  ['Food', 'Beauty', 'Govt'],
#  ['Tupperware', 'Food', 'Clothing & Apparel', 'Pet Care', 'Chemical'],
#  ['Clothing & Apparel', 'IT Sector'],
#  ['Food', 'Media'],
#  ['Food', 'Food', 'Agriculture'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Food',
#   'Games & Toys',
#   'Construction'],
#  ['Footwear & Shoes',
#   'Food',
#   'Furniture',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'IT Sector'],
#  ['Food', 'Electronics & Gadgets', 'IT Sector'],
#  ['Furniture', 'Clothing & Apparel', 'Media'],
#  ['Food', 'Furniture', 'Media'],
#  ['Food', 'Food', 'IT Sector'],
#  ['Food', 'Healthcare'],
#  ['Food', 'Retail'],
#  ['Clothing & Apparel', 'Hospitality'],
#  ['Clothing & Apparel', 'Media'],
#  ['Clothing & Apparel', 'Lawyer'],
#  ['Furniture',
#   'Food',
#   'Hand & Power Tools',
#   'Food',
#   'Food',
#   'Clothing & Apparel',
#   'Beauty',
#   'Food Processing'],
#  ['Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Automobile'],
#  ['Footwear & Shoes', 'Household items', 'Electronics & Gadgets', 'Chemical'],
#  ['Footwear & Shoes',
#   'Food',
#   'Food',
#   'Footwear & Shoes',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Govt'],
#  ['Food', 'Food', 'Agriculture'],
#  ['Clothing & Apparel', 'Household items', 'Chemical'],
#  ['Furniture',
#   'Footwear & Shoes',
#   'Food',
#   'Games & Toys',
#   'Food',
#   'Food',
#   'Household items',
#   'Chemical'],
#  ['Food',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Media'],
#  ['Food',
#   'Food',
#   'Decor',
#   'Electronics & Gadgets',
#   'Decor',
#   'Electronics & Gadgets',
#   'Household items',
#   'Pet Care',
#   'Aviation'],
#  ['Clothing & Apparel', 'IT Sector'],
#  ['Food', 'Clothing & Apparel', 'Electronics & Gadgets', 'Banking'],
#  ['Food', 'Beauty', 'Hospitality'],
#  ['Furniture', 'Electronics & Gadgets', 'Food Processing'],
#  ['Food', 'Footwear & Shoes', 'Food', 'Electronics & Gadgets', 'IT Sector'],
#  ['Auto',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Aviation'],
#  ['Food',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Household items',
#   'Beauty',
#   'IT Sector'],
#  ['Footwear & Shoes', 'Agriculture'],
#  ['Clothing & Apparel', 'Chemical'],
#  ['Household items', 'Aviation'],
#  ['Footwear & Shoes', 'Agriculture'],
#  ['Food', 'Food', 'Food', 'Govt'],
#  ['Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Govt'],
#  ['Footwear & Shoes',
#   'Food',
#   'Food',
#   'Food',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Food',
#   'Clothing & Apparel',
#   'Media'],
#  ['Electronics & Gadgets', 'Agriculture'],
#  ['Veterinary', 'Hospitality'],
#  ['Auto',
#   'Tupperware',
#   'Food',
#   'Electronics & Gadgets',
#   'Books',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Office',
#   'Office',
#   'Aviation'],
#  ['Household items',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Construction'],
#  ['Food', 'Pet Care', 'Food Processing'],
#  ['Food', 'Clothing & Apparel', 'Media'],
#  ['Footwear & Shoes', 'IT Sector'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Office',
#   'Retail'],
#  ['Electronics & Gadgets', 'IT Sector'],
#  ['Food', 'Banking'],
#  ['Clothing & Apparel', 'Media'],
#  ['Hand & Power Tools', 'Food', 'Food', 'Household items', 'Banking'],
#  ['Food', 'Automobile'],
#  ['Food', 'Footwear & Shoes', 'Food', 'Clothing & Apparel', 'Automobile'],
#  ['Clothing & Apparel', 'Chemical'],
#  ['Footwear & Shoes',
#   'Furniture',
#   'Food',
#   'Sports Products',
#   'Beauty',
#   'Food',
#   'Household items',
#   'Chemical'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Hospitality'],
#  ['Food', 'Electronics & Gadgets', 'Household items', 'IT Sector'],
#  ['Footwear & Shoes', 'Household items', 'Banking'],
#  ['Food', 'Food', 'Clothing & Apparel', 'Agriculture'],
#  ['Food', 'Games & Toys', 'Media'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Footwear & Shoes',
#   'Food Processing'],
#  ['Books',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Aviation'],
#  ['Food', 'Food', 'Tupperware', 'IT Sector'],
#  ['Footwear & Shoes', 'Footwear & Shoes', 'Footwear & Shoes', 'IT Sector'],
#  ['Food', 'Clothing & Apparel', 'Govt'],
#  ['Food', 'Office', 'Lawyer'],
#  ['Food', 'Clothing & Apparel', 'Clothing & Apparel', 'Chemical'],
#  ['Auto', 'Footwear & Shoes', 'Beauty', 'Sports Products', 'Banking'],
#  ['Footwear & Shoes', 'Chemical'],
#  ['Sports Products', 'Banking'],
#  ['Footwear & Shoes',
#   'Games & Toys',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Hospitality'],
#  ['Auto', 'Food', 'Games & Toys', 'Govt'],
#  ['Footwear & Shoes', 'Food', 'Electronics & Gadgets', 'Chemical'],
#  ['Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Household items',
#   'Clothing & Apparel',
#   'Banking'],
#  ['Electronics & Gadgets', 'Clothing & Apparel', 'Chemical'],
#  ['Food', 'Clothing & Apparel', 'Beauty', 'Chemical'],
#  ['Food', 'Banking'],
#  ['Food', 'Clothing & Apparel', 'Banking'],
#  ['Food', 'Banking'],
#  ['Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Automobile'],
#  ['Footwear & Shoes', 'Food', 'Beauty', 'Banking'],
#  ['Clothing & Apparel', 'Aviation'],
#  ['Food',
#   'Food',
#   'Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Household items',
#   'Electronics & Gadgets',
#   'Automobile'],
#  ['Clothing & Apparel', 'Lawyer'],
#  ['Clothing & Apparel', 'Chemical'],
#  ['Footwear & Shoes',
#   'Food',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Books',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Lawyer'],
#  ['Games & Toys', 'Banking'],
#  ['Food',
#   'Food',
#   'Footwear & Shoes',
#   'Food',
#   'Games & Toys',
#   'Clothing & Apparel',
#   'Food',
#   'Electronics & Gadgets',
#   'Food',
#   'Clothing & Apparel',
#   'Healthcare'],
#  ['Sports Products',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Aviation'],
#  ['Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Healthcare'],
#  ['Food',
#   'Games & Toys',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Healthcare'],
#  ['Footwear & Shoes', 'Pet Care', 'Aviation'],
#  ['Clothing & Apparel', 'Banking'],
#  ['Pet Care', 'Hospitality'],
#  ['Food', 'Banking'],
#  ['Food', 'Lawyer'],
#  ['Food', 'Furniture', 'Food', 'Household items', 'Chemical'],
#  ['Footwear & Shoes', 'Food', 'Electronics & Gadgets', 'IT Sector'],
#  ['Games & Toys',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Food Processing'],
#  ['Food', 'Electronics & Gadgets', 'Electronics & Gadgets', 'Banking'],
#  ['Furniture',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Household items',
#   'Beauty',
#   'Household items',
#   'Construction'],
#  ['Sports Products', 'Healthcare'],
#  ['Food',
#   'Furniture',
#   'Clothing & Apparel',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Food',
#   'Aviation'],
#  ['Furniture', 'Food', 'Healthcare'],
#  ['Beauty', 'Govt'],
#  ['Footwear & Shoes', 'Aviation'],
#  ['Food', 'Sports Products', 'Pet Care', 'IT Sector'],
#  ['Sports Products', 'Clothing & Apparel', 'IT Sector'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Beauty',
#   'Clothing & Apparel',
#   'IT Sector'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Chemical'],
#  ['Furniture',
#   'Food',
#   'Electronics & Gadgets',
#   'Household items',
#   'Healthcare'],
#  ['Food',
#   'Tupperware',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'IT Sector'],
#  ['Clothing & Apparel', 'IT Sector'],
#  ['Food', 'Clothing & Apparel', 'Clothing & Apparel', 'Govt'],
#  ['Electronics & Gadgets', 'Chemical'],
#  ['Food',
#   'Sports Products',
#   'Food',
#   'Food',
#   'Clothing & Apparel',
#   'Beauty',
#   'Office',
#   'Healthcare'],
#  ['Clothing & Apparel', 'Chemical'],
#  ['Food', 'Electronics & Gadgets', 'IT Sector'],
#  ['Food', 'Media'],
#  ['Auto', 'Food', 'Govt'],
#  ['Pet Care', 'Construction'],
#  ['Footwear & Shoes',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Healthcare'],
#  ['Clothing & Apparel', 'Construction'],
#  ['Clothing & Apparel', 'Healthcare'],
#  ['Food', 'IT Sector'],
#  ['Games & Toys',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Automobile'],
#  ['Food', 'Clothing & Apparel', 'Retail'],
#  ['Food', 'Beauty', 'Healthcare'],
#  ['Electronics & Gadgets', 'Healthcare'],
#  ['Games & Toys', 'Electronics & Gadgets', 'IT Sector'],
#  ['Food', 'Banking'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Beauty',
#   'Hospitality'],
#  ['Footwear & Shoes',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Pet Care',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Healthcare'],
#  ['Food', 'Household items', 'Hospitality'],
#  ['Clothing & Apparel', 'Healthcare'],
#  ['Food', 'Household items', 'Aviation'],
#  ['Veterinary', 'Retail'],
#  ['Clothing & Apparel', 'Electronics & Gadgets', 'Aviation'],
#  ['Beauty', 'Clothing & Apparel', 'Healthcare'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Furniture',
#   'Food',
#   'Games & Toys',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Lawyer'],
#  ['Food', 'Food', 'Food', 'Clothing & Apparel', 'Govt'],
#  ['Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Banking'],
#  ['Furniture',
#   'Furniture',
#   'Furniture',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Pet Care',
#   'Pet Care',
#   'Banking'],
#  ['Footwear & Shoes',
#   'Furniture',
#   'Electronics & Gadgets',
#   'Books',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Household items',
#   'Pet Care',
#   'Automobile'],
#  ['Electronics & Gadgets', 'Healthcare'],
#  ['Food', 'Tupperware', 'Hospitality'],
#  ['Food', 'Electronics & Gadgets', 'Electronics & Gadgets', 'Healthcare'],
#  ['Sports Products', 'Clothing & Apparel', 'Chemical'],
#  ['Pet Care', 'Textile'],
#  ['Clothing & Apparel', 'Household items', 'Healthcare'],
#  ['Furniture', 'Footwear & Shoes', 'Chemical'],
#  ['Food', 'Healthcare'],
#  ['Clothing & Apparel', 'Govt'],
#  ['Food',
#   'Auto',
#   'Food',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Household items',
#   'Office',
#   'IT Sector'],
#  ['Electronics & Gadgets', 'Healthcare'],
#  ['Footwear & Shoes', 'Electronics & Gadgets', 'Chemical'],
#  ['Beauty', 'Banking'],
#  ['Food', 'Chemical'],
#  ['Food',
#   'Food',
#   'Food',
#   'Furniture',
#   'Food',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Household items',
#   'Household items',
#   'Veterinary',
#   'IT Sector'],
#  ['Sports Products', 'Banking'],
#  ['Food',
#   'Food',
#   'Food',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Household items',
#   'Media'],
#  ['Games & Toys', 'Govt'],
#  ['Food', 'Food', 'IT Sector'],
#  ['Furniture', 'Electronics & Gadgets', 'Aviation'],
#  ['Food', 'IT Sector'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Food',
#   'Footwear & Shoes',
#   'Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Lawyer'],
#  ['Food', 'Food', 'Media'],
#  ['Food', 'IT Sector'],
#  ['Electronics & Gadgets', 'Healthcare'],
#  ['Food', 'Clothing & Apparel', 'Electronics & Gadgets', 'IT Sector'],
#  ['Auto', 'Automobile'],
#  ['Food', 'Beauty', 'Aviation'],
#  ['Electronics & Gadgets', 'Banking'],
#  ['Electronics & Gadgets', 'IT Sector'],
#  ['Food',
#   'Food',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Beauty',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Media'],
#  ['Food', 'Sports Products', 'Govt'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Household items',
#   'Govt'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Food',
#   'Clothing & Apparel',
#   'Agriculture'],
#  ['Footwear & Shoes', 'Clothing & Apparel', 'Aviation'],
#  ['Electronics & Gadgets', 'Construction'],
#  ['Clothing & Apparel', 'Hospitality'],
#  ['Clothing & Apparel', 'Chemical'],
#  ['Food', 'Healthcare'],
#  ['Games & Toys',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Household items',
#   'Banking'],
#  ['Food', 'Banking'],
#  ['Electronics & Gadgets', 'Construction'],
#  ['Food',
#   'Food',
#   'Food',
#   'Games & Toys',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Agriculture'],
#  ['Food', 'IT Sector'],
#  ['Footwear & Shoes', 'Construction'],
#  ['Food', 'Clothing & Apparel', 'Healthcare'],
#  ['Electronics & Gadgets', 'Electronics & Gadgets', 'Aviation'],
#  ['Furniture', 'Electronics & Gadgets', 'Lawyer'],
#  ['Food', 'Clothing & Apparel', 'Clothing & Apparel', 'Textile'],
#  ['Footwear & Shoes', 'Food', 'Lawyer'],
#  ['Electronics & Gadgets', 'Electronics & Gadgets', 'Healthcare'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'IT Sector'],
#  ['Food', 'Clothing & Apparel', 'Agriculture'],
#  ['Food', 'Textile'],
#  ['Electronics & Gadgets', 'Footwear & Shoes', 'Food Processing'],
#  ['Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Beauty',
#   'Banking'],
#  ['Food', 'Household items', 'Clothing & Apparel', 'IT Sector'],
#  ['Food', 'Auto', 'Footwear & Shoes', 'Healthcare'],
#  ['Food',
#   'Games & Toys',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Decor',
#   'Clothing & Apparel',
#   'Pet Care',
#   'Clothing & Apparel',
#   'Chemical'],
#  ['Games & Toys', 'Banking'],
#  ['Food', 'Clothing & Apparel', 'Media'],
#  ['Food',
#   'Food',
#   'Stationery',
#   'Clothing & Apparel',
#   'Beauty',
#   'Beauty',
#   'Veterinary',
#   'Aviation'],
#  ['Food', 'Electronics & Gadgets', 'IT Sector'],
#  ['Games & Toys', 'Clothing & Apparel', 'Retail'],
#  ['Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Furniture',
#   'Food',
#   'Household items',
#   'Food Processing'],
#  ['Footwear & Shoes', 'Stationery', 'Pet Care', 'Retail'],
#  ['Food', 'Lawyer'],
#  ['Clothing & Apparel', 'Lawyer'],
#  ['Furniture',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Food',
#   'Clothing & Apparel',
#   'Aviation'],
#  ['Footwear & Shoes', 'Aviation'],
#  ['Clothing & Apparel', 'Chemical'],
#  ['Clothing & Apparel', 'Aviation'],
#  ['Beauty', 'Aviation'],
#  ['Books', 'Electronics & Gadgets', 'Electronics & Gadgets', 'Chemical'],
#  ['Tupperware',
#   'Food',
#   'Footwear & Shoes',
#   'Food',
#   'Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Beauty',
#   'IT Sector'],
#  ['Clothing & Apparel', 'IT Sector'],
#  ['Clothing & Apparel', 'Aviation'],
#  ['Stationery',
#   'Furniture',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Chemical'],
#  ['Food', 'Sports Products', 'IT Sector'],
#  ['Electronics & Gadgets', 'Household items', 'Veterinary', 'Retail'],
#  ['Footwear & Shoes',
#   'Food',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Household items',
#   'Retail'],
#  ['Furniture', 'Agriculture'],
#  ['Clothing & Apparel', 'IT Sector'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Food',
#   'Food',
#   'Sports Products',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Games & Toys',
#   'Healthcare'],
#  ['Food', 'Retail'],
#  ['Stationery',
#   'Footwear & Shoes',
#   'Food',
#   'Food',
#   'Games & Toys',
#   'Stationery',
#   'Food',
#   'Sports Products',
#   'Stationery',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Chemical'],
#  ['Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Beauty',
#   'IT Sector'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Electronics & Gadgets',
#   'Banking'],
#  ['Food', 'Clothing & Apparel', 'Office', 'Banking'],
#  ['Footwear & Shoes',
#   'Food',
#   'Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Beauty',
#   'Govt'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Automobile'],
#  ['Food', 'Electronics & Gadgets', 'IT Sector'],
#  ['Games & Toys', 'Food', 'IT Sector'],
#  ['Clothing & Apparel', 'Agriculture'],
#  ['Food', 'Household items', 'Banking'],
#  ['Clothing & Apparel', 'Food Processing'],
#  ['Sports Products', 'Electronics & Gadgets', 'Food', 'Lawyer'],
#  ['Footwear & Shoes', 'Food', 'Games & Toys', 'Clothing & Apparel', 'Lawyer'],
#  ['Footwear & Shoes', 'Chemical'],
#  ['Food', 'Electronics & Gadgets', 'Office', 'Healthcare'],
#  ['Food', 'Beauty', 'Clothing & Apparel', 'Healthcare'],
#  ['Electronics & Gadgets', 'IT Sector'],
#  ['Games & Toys', 'Food Processing'],
#  ['Food', 'Automobile'],
#  ['Electronics & Gadgets', 'Healthcare'],
#  ['Food',
#   'Books',
#   'Food',
#   'Electronics & Gadgets',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Food',
#   'Aviation'],
#  ['Footwear & Shoes', 'Beauty', 'Healthcare'],
#  ['Food', 'Lawyer'],
#  ['Clothing & Apparel', 'Hospitality'],
#  ['Footwear & Shoes',
#   'Food',
#   'Sports Products',
#   'Food',
#   'Beauty',
#   'Electronics & Gadgets',
#   'Food',
#   'Banking'],
#  ['Auto',
#   'Food',
#   'Food',
#   'Furniture',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Household items',
#   'Banking'],
#  ['Footwear & Shoes', 'Clothing & Apparel', 'Office', 'Govt'],
#  ['Food', 'Household items', 'Media'],
#  ['Food', 'Footwear & Shoes', 'Aviation'],
#  ['Furniture', 'Clothing & Apparel', 'Clothing & Apparel', 'Automobile'],
#  ['Furniture',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Media'],
#  ['Food', 'Aviation'],
#  ['Clothing & Apparel', 'Healthcare'],
#  ['Electronics & Gadgets', 'Clothing & Apparel', 'Chemical'],
#  ['Clothing & Apparel', 'Household items', 'Construction'],
#  ['Food', 'Clothing & Apparel', 'Media'],
#  ['Books',
#   'Decor',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Books',
#   'Household items',
#   'Retail'],
#  ['Food',
#   'Food',
#   'Food',
#   'Food',
#   'Games & Toys',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Electronics & Gadgets',
#   'Veterinary',
#   'Veterinary',
#   'IT Sector'],
#  ['Electronics & Gadgets', 'Healthcare'],
#  ['Food', 'Lawyer'],
#  ['Electronics & Gadgets', 'Healthcare'],
#  ['Food', 'Beauty', 'Pet Care', 'Beauty', 'Automobile'],
#  ['Food', 'IT Sector'],
#  ['Sports Products', 'Books', 'Automobile'],
#  ['Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Footwear & Shoes',
#   'Household items',
#   'Beauty',
#   'Govt'],
#  ['Food', 'Clothing & Apparel', 'Lawyer'],
#  ['Clothing & Apparel', 'Healthcare'],
#  ['Clothing & Apparel', 'Banking'],
#  ['Food', 'Aviation'],
#  ['Games & Toys', 'Electronics & Gadgets', 'Retail'],
#  ['Footwear & Shoes',
#   'Games & Toys',
#   'Clothing & Apparel',
#   'Beauty',
#   'Clothing & Apparel',
#   'Beauty',
#   'Hospitality'],
#  ['Furniture',
#   'Furniture',
#   'Food',
#   'Sports Products',
#   'Footwear & Shoes',
#   'Food',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Office',
#   'Chemical'],
#  ['Electronics & Gadgets', 'Hospitality'],
#  ['Beauty', 'Aviation'],
#  ['Electronics & Gadgets', 'IT Sector'],
#  ['Furniture', 'Sports Products', 'Food', 'Automobile'],
#  ['Electronics & Gadgets',
#   'Food',
#   'Clothing & Apparel',
#   'Food',
#   'Household items',
#   'Food Processing'],
#  ['Games & Toys',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Veterinary',
#   'Retail'],
#  ['Auto',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Hand & Power Tools',
#   'Banking'],
#  ['Tupperware', 'IT Sector'],
#  ['Electronics & Gadgets', 'Banking'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Food',
#   'Electronics & Gadgets',
#   'Media'],
#  ['Clothing & Apparel', 'IT Sector'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Food',
#   'IT Sector'],
#  ['Games & Toys', 'Household items', 'Aviation'],
#  ['Food', 'Electronics & Gadgets', 'Electronics & Gadgets', 'Aviation'],
#  ['Tupperware',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Govt'],
#  ['Food', 'Food', 'Food', 'Sports Products', 'IT Sector'],
#  ['Games & Toys',
#   'Clothing & Apparel',
#   'Food',
#   'Electronics & Gadgets',
#   'Books',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Govt'],
#  ['Decor', 'Clothing & Apparel', 'IT Sector'],
#  ['Clothing & Apparel', 'Electronics & Gadgets', 'Hospitality'],
#  ['Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Decor',
#   'Food',
#   'Household items',
#   'Household items',
#   'IT Sector'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Food',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Clothing & Apparel',
#   'Construction'],
#  ['Beauty', 'Healthcare'],
#  ['Household items', 'Lawyer'],
#  ['Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Games & Toys',
#   'Banking'],
#  ['Clothing & Apparel', 'Lawyer'],
#  ['Food', 'Food', 'Sports Products', 'Clothing & Apparel', 'Automobile'],
#  ['Auto',
# ...
#  ['Food', 'Healthcare'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Household items',
#   'Clothing & Apparel',
#   'Banking'],
#  ['Furniture', 'Household items', 'IT Sector'],
#  ['Food',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Food',
#   'Beauty',
#   'Household items',
#   'Clothing & Apparel',
#   'Aviation'],
#  ['Clothing & Apparel', 'Banking'],
#  ['Clothing & Apparel', 'Healthcare'],
#  ['Games & Toys',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Pet Care',
#   'Banking'],
#  ['Beauty', 'IT Sector'],
#  ['Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Beauty',
#   'IT Sector'],
#  ['Footwear & Shoes',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Beauty',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Food',
#   'Clothing & Apparel',
#   'IT Sector'],
#  ['Clothing & Apparel', 'IT Sector'],
#  ['Food', 'Household items', 'Aviation'],
#  ['Footwear & Shoes',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Food Processing'],
#  ['Food', 'Chemical'],
#  ['Food',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Automobile'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Books',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Food',
#   'Banking'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Food',
#   'Food',
#   'Footwear & Shoes',
#   'Sports Products',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Games & Toys',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Food',
#   'Clothing & Apparel',
#   'Govt'],
#  ['Pet Care', 'Chemical'],
#  ['Food', 'Furniture', 'Electronics & Gadgets', 'IT Sector'],
#  ['Food', 'Clothing & Apparel', 'Govt'],
#  ['Beauty', 'Textile'],
#  ['Food', 'Electronics & Gadgets', 'Govt'],
#  ['Food', 'Clothing & Apparel', 'Healthcare'],
#  ['Furniture', 'Healthcare'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Games & Toys',
#   'Food',
#   'Games & Toys',
#   'Furniture',
#   'Furniture',
#   'Food',
#   'Games & Toys',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Food',
#   'Clothing & Apparel',
#   'Construction'],
#  ['Stationery', 'Footwear & Shoes', 'Electronics & Gadgets', 'Retail'],
#  ['Electronics & Gadgets',
#   'Games & Toys',
#   'Electronics & Gadgets',
#   'Decor',
#   'Clothing & Apparel',
#   'Banking'],
#  ['Food',
#   'Clothing & Apparel',
#   'Beauty',
#   'Beauty',
#   'Household items',
#   'Household items',
#   'Clothing & Apparel',
#   'Automobile'],
#  ['Pet Care', 'Healthcare'],
#  ['Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Household items',
#   'Household items',
#   'IT Sector'],
#  ['Electronics & Gadgets', 'Retail'],
#  ['Food',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Veterinary',
#   'IT Sector'],
#  ['Clothing & Apparel', 'Hospitality'],
#  ['Footwear & Shoes', 'Food Processing'],
#  ['Food', 'Aviation'],
#  ['Pet Care', 'Textile'],
#  ['Food', 'Auto', 'Footwear & Shoes', 'Beauty', 'Media'],
#  ['Clothing & Apparel', 'Banking'],
#  ['Food', 'Clothing & Apparel', 'Electronics & Gadgets', 'Banking'],
#  ['Food',
#   'Footwear & Shoes',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Healthcare'],
#  ['Household items', 'Hospitality'],
#  ['Furniture', 'Clothing & Apparel', 'Hospitality'],
#  ['Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'IT Sector'],
#  ['Food', 'Clothing & Apparel', 'Banking'],
#  ['Sports Products', 'Automobile'],
#  ['Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Footwear & Shoes',
#   'IT Sector'],
#  ['Beauty', 'Govt'],
#  ['Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Household items',
#   'Retail'],
#  ['Footwear & Shoes',
#   'Food',
#   'Food',
#   'Games & Toys',
#   'Clothing & Apparel',
#   'Banking'],
#  ['Furniture', 'Aviation'],
#  ['Games & Toys',
#   'Clothing & Apparel',
#   'Household items',
#   'Household items',
#   'Clothing & Apparel',
#   'Lawyer'],
#  ['Footwear & Shoes',
#   'Food',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'IT Sector'],
#  ['Clothing & Apparel', 'Electronics & Gadgets', 'Banking'],
#  ['Footwear & Shoes', 'Furniture', 'Clothing & Apparel', 'Aviation'],
#  ['Clothing & Apparel', 'Clothing & Apparel', 'Aviation'],
#  ['Footwear & Shoes', 'Books', 'Clothing & Apparel', 'Banking'],
#  ['Games & Toys', 'Clothing & Apparel', 'Aviation'],
#  ['Electronics & Gadgets', 'Clothing & Apparel', 'IT Sector'],
#  ['Household items', 'Aviation'],
#  ['Footwear & Shoes', 'Clothing & Apparel', 'Banking'],
#  ['Footwear & Shoes',
#   'Food',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Household items',
#   'Healthcare'],
#  ['Food', 'Healthcare'],
#  ['Food',
#   'Games & Toys',
#   'Beauty',
#   'Clothing & Apparel',
#   'Household items',
#   'Aviation'],
#  ['Footwear & Shoes', 'Footwear & Shoes', 'Food', 'Pet Care', 'Banking'],
#  ['Furniture', 'Food', 'Clothing & Apparel', 'Beauty', 'IT Sector'],
#  ['Footwear & Shoes',
#   'Food',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Govt'],
#  ['Food', 'Food', 'Office', 'Retail'],
#  ['Food', 'Aviation'],
#  ['Sports Products',
#   'Clothing & Apparel',
#   'Stationery',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Govt'],
#  ['Electronics & Gadgets', 'Aviation'],
#  ['Food', 'Food', 'Healthcare'],
#  ['Food', 'Clothing & Apparel', 'Household items', 'Pet Care', 'Healthcare'],
#  ['Furniture',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Household items',
#   'IT Sector'],
#  ['Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Household items',
#   'Aviation'],
#  ['Food', 'Agriculture'],
#  ['Electronics & Gadgets', 'Healthcare'],
#  ['Food', 'Pet Care', 'Media'],
#  ['Food', 'Clothing & Apparel', 'Games & Toys', 'Household items', 'Media'],
#  ['Clothing & Apparel', 'Healthcare'],
#  ['Stationery', 'Govt'],
#  ['Auto',
#   'Food',
#   'Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Furniture',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Footwear & Shoes',
#   'Beauty',
#   'Beauty',
#   'Electronics & Gadgets',
#   'IT Sector'],
#  ['Food', 'Books', 'Govt'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'IT Sector'],
#  ['Stationery', 'Electronics & Gadgets', 'Agriculture'],
#  ['Food',
#   'Footwear & Shoes',
#   'Stationery',
#   'Clothing & Apparel',
#   'Pet Care',
#   'Construction'],
#  ['Footwear & Shoes', 'Food', 'Clothing & Apparel', 'Office', 'Lawyer'],
#  ['Furniture', 'Banking'],
#  ['Footwear & Shoes',
#   'Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Household items',
#   'IT Sector'],
#  ['Electronics & Gadgets', 'Footwear & Shoes', 'Healthcare'],
#  ['Furniture', 'Hospitality'],
#  ['Games & Toys', 'Automobile'],
#  ['Food', 'Automobile'],
#  ['Pet Care', 'Banking'],
#  ['Auto',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Furniture',
#   'IT Sector'],
#  ['Footwear & Shoes', 'Banking'],
#  ['Games & Toys', 'Clothing & Apparel', 'Household items', 'Hospitality'],
#  ['Electronics & Gadgets', 'Food', 'Veterinary', 'Chemical'],
#  ['Food', 'Hospitality'],
#  ['Furniture',
#   'Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Household items',
#   'Govt'],
#  ['Food', 'Electronics & Gadgets', 'Aviation'],
#  ['Sports Products', 'Clothing & Apparel', 'Automobile'],
#  ['Tupperware',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Aviation'],
#  ['Footwear & Shoes',
#   'Decor',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Automobile'],
#  ['Furniture', 'Healthcare'],
#  ['Food',
#   'Food',
#   'Footwear & Shoes',
#   'Decor',
#   'Clothing & Apparel',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Food',
#   'Household items',
#   'Aviation'],
#  ['Footwear & Shoes', 'Media'],
#  ['Pet Care', 'Govt'],
#  ['Auto',
#   'Food',
#   'Food',
#   'Games & Toys',
#   'Clothing & Apparel',
#   'Food',
#   'Beauty',
#   'Clothing & Apparel',
#   'Household items',
#   'Household items',
#   'Veterinary',
#   'Construction'],
#  ['Food',
#   'Food',
#   'Food',
#   'Food',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Healthcare'],
#  ['Food', 'Hospitality'],
#  ['Food', 'Food', 'Electronics & Gadgets', 'Govt'],
#  ['Games & Toys',
#   'Food',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Textile'],
#  ['Food', 'Lawyer'],
#  ['Food', 'Clothing & Apparel', 'Retail'],
#  ['Electronics & Gadgets', 'Aviation'],
#  ['Electronics & Gadgets', 'Banking'],
#  ['Tupperware',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Household items',
#   'Media'],
#  ['Clothing & Apparel', 'Healthcare'],
#  ['Stationery',
#   'Food',
#   'Sports Products',
#   'Electronics & Gadgets',
#   'Construction'],
#  ['Food', 'Clothing & Apparel', 'Healthcare'],
#  ['Electronics & Gadgets', 'Healthcare'],
#  ['Stationery',
#   'Food',
#   'Food',
#   'Food',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Household items',
#   'Media'],
#  ['Food',
#   'Sports Products',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Stationery',
#   'Food',
#   'Household items',
#   'Lawyer'],
#  ['Food',
#   'Footwear & Shoes',
#   'Books',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Healthcare'],
#  ['Furniture',
#   'Footwear & Shoes',
#   'Food',
#   'Footwear & Shoes',
#   'Games & Toys',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Games & Toys',
#   'Pet Care',
#   'Banking'],
#  ['Electronics & Gadgets', 'IT Sector'],
#  ['Footwear & Shoes', 'Tupperware', 'Textile'],
#  ['Footwear & Shoes', 'Food', 'Footwear & Shoes', 'Food', 'Pet Care', 'Govt'],
#  ['Electronics & Gadgets', 'Automobile'],
#  ['Electronics & Gadgets', 'Construction'],
#  ['Food', 'Lawyer'],
#  ['Food',
#   'Food',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Agriculture'],
#  ['Sports Products',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Beauty',
#   'Aviation'],
#  ['Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Healthcare'],
#  ['Food', 'Auto', 'Clothing & Apparel', 'Electronics & Gadgets', 'Aviation'],
#  ['Decor', 'Hospitality'],
#  ['Food', 'Food', 'Clothing & Apparel', 'Household items', 'Automobile'],
#  ['Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Food',
#   'Pet Care',
#   'Media'],
#  ['Food', 'Healthcare'],
#  ['Food', 'Clothing & Apparel', 'Aviation'],
#  ['Clothing & Apparel', 'Media'],
#  ['Electronics & Gadgets', 'Electronics & Gadgets', 'IT Sector'],
#  ['Food',
#   'Footwear & Shoes',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Healthcare'],
#  ['Clothing & Apparel', 'Clothing & Apparel', 'Chemical'],
#  ['Food', 'Electronics & Gadgets', 'IT Sector'],
#  ['Electronics & Gadgets',
#   'Household items',
#   'Clothing & Apparel',
#   'Hospitality'],
#  ['Furniture',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Banking'],
#  ['Hand & Power Tools', 'Games & Toys', 'Electronics & Gadgets', 'Media'],
#  ['Footwear & Shoes', 'Books', 'Clothing & Apparel', 'Automobile'],
#  ['Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Household items',
#   'IT Sector'],
#  ['Stationery',
#   'Footwear & Shoes',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Household items',
#   'IT Sector'],
#  ['Footwear & Shoes',
#   'Food',
#   'Footwear & Shoes',
#   'Food',
#   'Food',
#   'Decor',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Pet Care',
#   'Office',
#   'Chemical'],
#  ['Electronics & Gadgets', 'Healthcare'],
#  ['Furniture', 'Food', 'Aviation'],
#  ['Footwear & Shoes',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Agriculture'],
#  ['Furniture', 'Food', 'Clothing & Apparel', 'Stationery', 'Aviation'],
#  ['Games & Toys', 'Food', 'Food', 'Aviation'],
#  ['Footwear & Shoes',
#   'Footwear & Shoes',
#   'Furniture',
#   'Furniture',
#   'Games & Toys',
#   'Food',
#   'Food Processing'],
#  ['Auto',
#   'Footwear & Shoes',
#   'Pet Care',
#   'Pet Care',
#   'Electronics & Gadgets',
#   'Automobile'],
#  ['Footwear & Shoes', 'Textile'],
#  ['Electronics & Gadgets', 'Aviation'],
#  ['Electronics & Gadgets', 'Household items', 'Household items', 'Automobile'],
#  ['Household items', 'Automobile'],
#  ['Food', 'Banking'],
#  ['Pet Care', 'Hospitality'],
#  ['Furniture', 'Electronics & Gadgets', 'Construction'],
#  ['Food', 'Sports Products', 'Clothing & Apparel', 'Textile'],
#  ['Household items', 'Hospitality'],
#  ['Footwear & Shoes', 'Food Processing'],
#  ['Food', 'Clothing & Apparel', 'Lawyer'],
#  ['Footwear & Shoes', 'Pet Care', 'Construction'],
#  ['Decor', 'Electronics & Gadgets', 'Hospitality'],
#  ['Food', 'Hospitality'],
#  ['Food', 'Govt'],
#  ['Clothing & Apparel', 'Hospitality'],
#  ['Food', 'Electronics & Gadgets', 'Aviation'],
#  ['Food', 'Food', 'Clothing & Apparel', 'IT Sector'],
#  ['Food', 'Lawyer'],
#  ['Food', 'Construction'],
#  ['Electronics & Gadgets', 'Construction'],
#  ['Sports Products', 'IT Sector'],
#  ['Food', 'Aviation'],
#  ['Office', 'Aviation'],
#  ['Food', 'Clothing & Apparel', 'Govt'],
#  ['Footwear & Shoes', 'Banking'],
#  ['Food',
#   'Electronics & Gadgets',
#   'Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Retail'],
#  ['Furniture', 'Clothing & Apparel', 'Sports Products', 'Chemical'],
#  ['Food', 'Media'],
#  ['Clothing & Apparel', 'Aviation'],
#  ['Sports Products', 'Retail'],
#  ['Food', 'Aviation'],
#  ['Food',
#   'Beauty',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'Automobile'],
#  ['Food', 'Food', 'Clothing & Apparel', 'Food', 'Lawyer'],
#  ['Food', 'Clothing & Apparel', 'Govt'],
#  ['Electronics & Gadgets', 'Aviation'],
#  ['Furniture', 'Govt'],
#  ['Food', 'Clothing & Apparel', 'Clothing & Apparel', 'Hospitality'],
#  ['Food', 'Clothing & Apparel', 'Food Processing'],
#  ['Electronics & Gadgets', 'Games & Toys', 'Banking'],
#  ['Auto', 'Banking'],
#  ['Food', 'Aviation'],
#  ['Food', 'Household items', 'Automobile'],
#  ['Electronics & Gadgets', 'Media'],
#  ['Food',
#   'Sports Products',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Food',
#   'Household items',
#   'Veterinary',
#   'Food Processing'],
#  ['Clothing & Apparel',
#   'Clothing & Apparel',
#   'Beauty',
#   'Footwear & Shoes',
#   'Furniture',
#   'Healthcare'],
#  ['Clothing & Apparel', 'Textile'],
#  ['Sports Products',
#   'Food',
#   'Clothing & Apparel',
#   'Clothing & Apparel',
#   'IT Sector'],
#  ['Food', 'Clothing & Apparel', 'Clothing & Apparel', 'Pet Care', 'Banking'],
#  ['Footwear & Shoes',
#   'Food',
#   'Food',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Automobile'],
#  ['Clothing & Apparel',
#   'Electronics & Gadgets',
#   'Electronics & Gadgets',
#   'Aviation'],
#  ['Footwear & Shoes', 'Games & Toys', 'Food', 'Household items', 'Retail'],
#  ['Food', 'Agriculture'],
#  ['Pet Care', 'Govt'],
#  ['Clothing & Apparel', 'Beauty', 'Aviation'],
#  ['Furniture',
#   'Footwear & Shoes',
#   'Games & Toys',
#   'Clothing & Apparel',
#   'Beauty',
#   'Footwear & Shoes',
#   'Pet Care',
#   'Household items',
#   'Construction'],
#  ['Food', 'Clothing & Apparel', 'IT Sector'],
#  ['Clothing & Apparel', 'Clothing & Apparel', 'Veterinary', 'Media'],
#  ...]

# %%
# Transform data
te = TransactionEncoder()
transactions = te.fit(data).transform(data) # or fit_transform(data)
# Create a dataframe from the data
df_encoded = pd.DataFrame(transactions, columns=te.columns_)
df_encoded
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       Agriculture   Auto  Automobile  Aviation  Banking  Beauty  Books  \
# 0           False  False       False      True    False   False  False
# 1            True  False       False     False    False   False  False
# 2           False  False        True     False    False   False  False
# 3           False  False       False     False    False   False  False
# 4           False  False       False     False    False   False  False
# ...           ...    ...         ...       ...      ...     ...    ...
# 3750        False  False       False     False    False   False  False
# 3751        False  False       False     False    False    True  False
# 3752        False  False       False     False    False   False  False
# 3753        False  False       False     False    False   False  False
# 3754        False  False       False     False    False   False  False
#
#       Chemical  Clothing & Apparel  Construction  ...  Lawyer  Media  Office  \
# 0        False               False         False  ...   False  False   False
# 1        False                True         False  ...   False  False   False
# 2        False               False         False  ...   False  False   False
# 3        False               False         False  ...   False  False   False
# 4        False               False         False  ...   False  False   False
# ...        ...                 ...           ...  ...     ...    ...     ...
# 3750     False                True         False  ...   False  False   False
# 3751      True                True         False  ...   False  False   False
# 3752     False                True         False  ...   False  False   False
# 3753     False                True         False  ...   False  False   False
# 3754     False               False         False  ...   False  False   False
#
#       Pet Care  Retail  Sports Products  Stationery  Textile  Tupperware  \
# 0        False   False            False       False    False       False
# 1        False   False            False       False    False       False
# 2        False   False            False       False    False       False
# 3        False    True            False       False    False       False
# 4        False   False             True       False    False       False
# ...        ...     ...              ...         ...      ...         ...
# 3750     False   False            False       False    False       False
# 3751     False   False             True       False    False       False
# 3752     False   False            False       False    False       False
# 3753     False   False            False       False    False       False
# 3754     False   False             True       False    False       False
#
#       Veterinary
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ...          ...
# 3750       False
# 3751       False
# 3752       False
# 3753       False
# 3754       False
#
# [3755 rows x 33 columns]

# %%
# Apply the Apriori algorithm to identify frequent itemsets
frequent_itemsets = apriori(df_encoded, min_support=0.005, use_colnames=True)

# Sort the frequent itemsets by support (descending order)
frequent_itemsets = frequent_itemsets.sort_values(by="support", ascending=False)

# Display the top frequent itemsets
print(frequent_itemsets.head())
# Out:
#      support                    itemsets
# 5   0.467909        (Clothing & Apparel)
# 7   0.452730                      (Food)
# 6   0.375499     (Electronics & Gadgets)
# 8   0.213316          (Footwear & Shoes)
# 24  0.207989  (Food, Clothing & Apparel)
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
rules = association_rules(frequent_itemsets, num_itemsets=frequent_itemsets.shape[0], metric="support", min_threshold=0.005)

rules = rules[(rules["lift"] > 1.2) & # 20% projected increase in purchase compared to general population
 (rules["antecedents"] == {"Banking"}) &  # For bankers
  rules["consequents"].apply(lambda x: len(x) == 1) ] # Single category recommendations.
rules.sort_values(by=["lift"])
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     antecedents     consequents  antecedent support  consequent support  \
# 617   (Banking)  (Games & Toys)            0.097736            0.094274
#
#       support  confidence      lift  representativity  leverage  conviction  \
# 617  0.013848    0.141689  1.502948               1.0  0.004634    1.055242
#
#      zhangs_metric   jaccard  certainty  kulczynski
# 617        0.37089  0.077728    0.05235    0.144291

# %% [markdown]
# Games and Toys stand out at a product category that is much more likely to be purchased by bankers than the average customer.
